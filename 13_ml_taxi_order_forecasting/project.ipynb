# %% [markdown]
# <a id="point0"></a>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-и-изучение-данных" data-toc-modified-id="Загрузка-и-изучение-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка и изучение данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Изучение-данных" data-toc-modified-id="Изучение-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Изучение данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Изменение типов данных</a></span></li><li><span><a href="#Обработка-дубликатов" data-toc-modified-id="Обработка-дубликатов-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Обработка дубликатов</a></span></li></ul></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Признак-datetime" data-toc-modified-id="Признак-datetime-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Признак <code>datetime</code></a></span></li><li><span><a href="#Признак-num_orders" data-toc-modified-id="Признак-num_orders-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Признак <code>num_orders</code></a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Создание-новых-признаков" data-toc-modified-id="Создание-новых-признаков-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Создание новых признаков</a></span><ul class="toc-item"><li><span><a href="#Скользящее-среднее" data-toc-modified-id="Скользящее-среднее-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Скользящее среднее</a></span></li><li><span><a href="#«Отстающие-значения»" data-toc-modified-id="«Отстающие-значения»-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>«Отстающие значения»</a></span></li></ul></li><li><span><a href="#Формирование-выборок" data-toc-modified-id="Формирование-выборок-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Формирование выборок</a></span></li></ul></li><li><span><a href="#Задача-прогнозирования" data-toc-modified-id="Задача-прогнозирования-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Задача прогнозирования</a></span><ul class="toc-item"><li><span><a href="#Прогноз-без-обучения" data-toc-modified-id="Прогноз-без-обучения-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Прогноз без обучения</a></span><ul class="toc-item"><li><span><a href="#Прогноз-константой" data-toc-modified-id="Прогноз-константой-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Прогноз константой</a></span></li><li><span><a href="#Прогноз-предыдущим-значением-ряда" data-toc-modified-id="Прогноз-предыдущим-значением-ряда-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Прогноз предыдущим значением ряда</a></span></li></ul></li><li><span><a href="#Прогноз-с-помощью-моделей-МО" data-toc-modified-id="Прогноз-с-помощью-моделей-МО-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Прогноз с помощью моделей МО</a></span><ul class="toc-item"><li><span><a href="#Формирование-пайплайна" data-toc-modified-id="Формирование-пайплайна-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Формирование пайплайна</a></span></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Обучение моделей</a></span></li><li><span><a href="#Анализ-моделей" data-toc-modified-id="Анализ-моделей-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Анализ моделей</a></span></li><li><span><a href="#Оценка-качества-модели-на-тестовых-данных" data-toc-modified-id="Оценка-качества-модели-на-тестовых-данных-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Оценка качества модели на тестовых данных</a></span></li><li><span><a href="#Проверка-модели-на-адекватность" data-toc-modified-id="Проверка-модели-на-адекватность-4.2.5"><span class="toc-item-num">4.2.5&nbsp;&nbsp;</span>Проверка модели на адекватность</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# #  Прогнозирование заказов такси
# **Описание проекта**
#
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Постройте модель для такого предсказания.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
# Вам нужно:
#
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами. Сделать тестовую выборку размером 10% от исходных данных.
# 4. Проверить данные на тестовой выборке и сделать выводы.
#
# **Описание данных**
# Данные лежат в файле `taxi.csv`. Количество заказов находится в столбце `num_orders` (от англ. *number of orders*, «число заказов»).
#
# **Цель исследования**: Подготовить прогнозные модели для определения количества заказов такси на следующий час.
#
# **Задачи исследования**:
# 1. Ознакомиться с имеющимися в распоряжении данными.
# 2. Произвести предварительную обработку данных.
# 3. Провести анализ данных.
# 4. Исследовать модели прогноза значений временного ряда.
# 5. Определить лучшую модель удовлетворяющую заданным критериям качества.
# 7. Представить результат и сделать выводы.

# %% [markdown]
# ## Загрузка и изучение данных
# Импорт необходимых для выполнения проекта библиотек:

# %%
# !pip install scikit-learn==1.3.2 -q

# %%
import pandas as pd              # Импорт библиотеки pandas
import matplotlib.pyplot as plt  # Импорт библиотеки для работы с графиками
import numpy as np               # Импорт библиотеки NumPy
from scipy import stats          # Импорт статистических функций из библиотеки SciPy

from statsmodels.tsa.seasonal import seasonal_decompose # Функция декомпозиции временного ряда
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf # Функция построения графиков ACF/PACF

from sklearn.model_selection import (train_test_split,# Функция для разбивки датасета на выборки
                                     TimeSeriesSplit, # Кросс-валидация для временных рядов
                                     GridSearchCV)    # Инструмент автоматизированного поиска гиперпараметров
from sklearn.metrics import mean_squared_error # Импорт метрики MSE
from sklearn.compose import ColumnTransformer # Импорт инструмента подготовки данных
from sklearn.preprocessing import FunctionTransformer # Инструмент интеграции функций в пайплайн
from sklearn.pipeline import Pipeline # Импорт Pipeline

# Импорт моделей 
from sklearn.tree import DecisionTreeRegressor # Дерево решений
from lightgbm import LGBMRegressor # Модель LightGBM
from catboost import CatBoostRegressor # Модель CatBoost

# %% [markdown]
# Установка вспомогательных настроек, функций и констант:

# %%
# формат вывода float-чисел датафрейма:
pd.options.display.float_format = ("{:.2f}".format)

# настройка отображения графиков:
plt.rcParams["figure.figsize"] = (15,7) # размер графиков по умолчанию:
plt.rcParams.update({'axes.grid' : True, 'grid.alpha': 0.33, 'grid.linestyle': '--'}) # отображение сетки:

# установка цветовой палитры:
color_list = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', 
               '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# переменные для форматирования шрифта при выводе информации:
green, red, bold, end = '\33[92m', '\33[91m', '\33[1m', '\33[0m'

# создание переменной псевдослучайности
RANDOM_STATE = 42

def dataset_info(df):
    """Функция для вывода общей информации о датасете"""
    print('• ' + '\33[4m' + 'Первые 10 строк датасета:' + end, f'[{df.dsc}]')
    display(df.head(10))
    print('• ' + '\33[4m' + 'Основная информация о датасете:' + end, f'[{df.dsc}]')

def stat_num(data_set, feature, rv=2, bins=50):
    """
    Функция отображения распределения числового признака.
    Для непрерывных величин строится диаграммы размаха и гистограммы распредления.
    Выводится описательная информация.
    """
    param = data_set[feature]
    dsr = param.describe()
    iqr = dsr['75%'] - dsr['25%']
    
    kde = stats.gaussian_kde(param)
    xx = np.linspace(dsr['min'], dsr['max'], bins)
    
    # конфигурация графиков:
    fig, axes = plt.subplots(nrows=1, ncols=2)
    # диаграмма размаха:
    param.plot(kind='box', ax=axes[0])
    axes[0].set_title('Разброс значений признака')
    axes[0].set_ylabel(feature_dsc[feature])
    
    # гистограмма:
    bns =  plt.hist(param, bins=bins, orientation='horizontal')
    scale = max(bns[0]) / max(kde(xx))
    # масштабированная линия плотности:
    plt.plot(0.9 * scale * kde(xx), xx)
    axes[1].set_title('Гистограмма распределения')
    axes[1].set_xlabel('Частота')
    axes[1].axhline(dsr['mean'], color='r', linestyle='--', label='Среднее значение')
    axes[1].axhline(dsr['50%'], color='r', linestyle=':', label='Медиана')
    axes[1].legend()
    plt.show()
    
    # описательная информация:
    print(f"Описательная информация для признака '{feature}':")
    print(bold + "Минимальное значение:" + end, 
          round(dsr['min'], 2), bold + "\t|\tМаксимальное значение:" + end, round(dsr['max'], 2))
    print(bold + "Среднее значение:" + end, f"{round(dsr['mean'], rv)}")
    print(bold + "Медиана:" + end, round(dsr['50%'], 2))
    print(bold + "Межквартильный размах IQR:" + end, round(iqr, rv))
    print(bold + "Границы нормальных значений:" + end, 
          f"от {round(max([dsr['25%'] - 1.5*iqr, dsr['min']]), rv)} до",
          f"{round(min([dsr['75%'] + 1.5*iqr, dsr['max']]), rv)}")
    
def show_gs_result(data, n=5):
    """
    Показывает 5 лучших по метрике моделей среди результатов GridSearchCV
    """
    result_reg = pd.DataFrame(data.cv_results_).sort_values('rank_test_score')[
    ['rank_test_score', 'param_models', 'mean_test_score','mean_fit_time','params']
    ]
    result_reg['mean_test_score'] = -result_reg['mean_test_score']
    result_reg['param_models'] = (result_reg['param_models']
                                  .astype('str')
                                  .str.replace('<catboost.*>','CatBoostRegressor', regex=True)
                                  .str.replace('\(.*','', regex=True))
    return result_reg.head(n)

def models_compare(df):
    """
    Визуализация сравнительных характеристик моделей:
    mean_test_score, mean_fit_time, time_pred
    """
    # Создаем график
    fig, ax1 = plt.subplots()  # Увеличиваем ширину для читаемости
    
    # Настройки для столбцов
    width = 0.15  # Уменьшаем ширину столбцов, чтобы вместить три
    x = range(df.shape[0])  # Позиции по оси X
    
    # Левая ось Y: mean_test_score
    ax1.bar([i - width for i in x], df['mean_test_score'], width, color=color_list[0], label='Средняя метрика')
    ax1.set_xlabel('Наименование моделей')
    ax1.set_ylabel('Метрика RMSE')
    ax1.tick_params(axis='y')
    ax1.set_xticks(x)
    ax1.set_xticklabels(df['param_models'])
    
    # Правая ось Y: mean_fit_time и time_pred
    ax2 = ax1.twinx()  # Создаем вторую ось Y
    ax2.bar([i for i in x], df['mean_fit_time'], width, color=color_list[1], label='Среднее время обучения')
    ax2.set_ylabel('Время (секунды)')
    ax2.tick_params(axis='y')
    
    # Заголовок и легенда
    plt.title('Сравнительные характеристики моделей')
    fig.legend(loc='upper center', bbox_to_anchor=(0.3, 0.94))  # Увеличиваем ncol до 3
    
    # Показываем график
    plt.tight_layout()
    plt.grid(visible=False)
    plt.show()

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ### Загрузка данных
# Загрузим данные в датафреймы:

# %%
data = pd.read_csv('/datasets/taxi.csv')

# %% [markdown]
# ### Изучение данных
# Выведем общую информацию об имеющихся данных:

# %%
print('• ' + '\33[4m' + 'Первые 10 строк датасета:' + end)
display(data.head(10))
print('\n• ' + '\33[4m' + 'Основная информация о датасете:' + end)
data.info()
# Out:
# • Первые 10 строк датасета:
#               datetime  num_orders
# 0  2018-03-01 00:00:00           9
# 1  2018-03-01 00:10:00          14
# 2  2018-03-01 00:20:00          28
# 3  2018-03-01 00:30:00          20
# 4  2018-03-01 00:40:00          32
# 5  2018-03-01 00:50:00          21
# 6  2018-03-01 01:00:00           7
# 7  2018-03-01 01:10:00           5
# 8  2018-03-01 01:20:00          17
# 9  2018-03-01 01:30:00          12
# • Основная информация о датасете:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26496 entries, 0 to 26495
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    26496 non-null  object
#  1   num_orders  26496 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 414.1+ KB

# %% [markdown]
# **Вывод**:
# * Датасет состоит из 26496 строк и 2 столбцов.
# * Набор данных представлен двумя признаками - `datetime` и `num_orders`.
# * Признаки имеют типы данных:
#   * `datetime` - object
#   * `num_orders` - int64
# * Данные не содержат пропусков.
# * Имеющиеся данные соответствуют описанию и структуре, заявленным заказчиком.
# * Значения ячеек выглядят реалистично.
# * Значения ячеек выглядят уникально.

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# На этапе первичного знакомства с данными выявлено:
# * ✅ Заголовки датасета соответствуют стандарту оформления данных, не требуют изменений.
# * ✅ Отсутствуют пропуски данных.

# %% [markdown]
# #### Изменение типов данных
# Для имеющихся данных отобразим 1 произвольную строку, а также строку с указанием типов данных:

# %%
pd.concat([data.sample(), 
    pd.DataFrame(data.dtypes, columns=['dtypes']).transpose()])
# Out:
#                    datetime num_orders
# 2155    2018-03-15 23:10:00         14
# dtypes               object      int64

# %% [markdown]
# * Признак `datetime` отображающий информацию о времени имеет тип данных `object`. Поскольку мы решаем задачу временных рядов, необходимо преобразовать тип данных к `datetime`
# * Признак `num_orders` отображающий информацию о количестве заказов имеет целочисленный тип данных `int64`. Изменений не требует.
#
# Преобразуем тип данных для признака `datetime`:

# %%
data['datetime'] = pd.to_datetime(data['datetime'])

# %% [markdown]
# Снова отобразим данные:

# %%
pd.concat([data.sample(), 
    pd.DataFrame(data.dtypes, columns=['dtypes']).transpose()])
# Out:
#                    datetime num_orders
# 8900    2018-05-01 19:20:00          9
# dtypes       datetime64[ns]      int64

# %% [markdown]
# **Вывод**:
# * признак `datetime` приведен к формату `datetime`
# * признак `num_orders` имеет подходящий тип - `int64`

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### Обработка дубликатов
# Отобразим количество явных дубликатов данных:

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Проверим, что значения даты и времени признака `datetime` расположены в хронологическом порядке:

# %%
data['datetime'].is_monotonic
# Out:
# True

# %% [markdown]
# Поскольку в признаке `datetime` нет дубликатов и он является монотонно возрастающей функцией установим его в качестве индекса:

# %%
data.set_index('datetime', inplace=True)
data.head(2)
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14

# %% [markdown]
# **Вывод**:
# * Полные дубликаты данных отсутствуют
# * Значения даты и времени признака `datetime` расположены в хронологическом порядке
# * Значения признака `datetime` установлены в качестве индекса

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ## Анализ данных
# Имеющиеся в распоряжении данные предствалены двумя признаками:
# * признак `datetime` содержит информацию о дате и времени
# * признак `num_orders` содержит информацию о количестве заказов такси для соответствующей временной метки.
#
# Зафиксирую описание признака:

# %%
feature_dsc = {'num_orders':'Количество заказов такси'}

# %% [markdown]
# ### Признак `datetime`
# Отобразим первые 10 строк датасета:

# %%
data.head(10)
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32
# 2018-03-01 00:50:00          21
# 2018-03-01 01:00:00           7
# 2018-03-01 01:10:00           5
# 2018-03-01 01:20:00          17
# 2018-03-01 01:30:00          12

# %% [markdown]
# Для признака `datetime` представлены данные о дате и времени с интервалом 10 минут.
#
# Поскольку задача проекта - 'прогнозирование количества заказов такси на следующий **час**' необходимо преобразовать данные, изменив интервал.
#
# Это можно сделать с помощью ресемплирования данных, в качестве функции агрегации используется сумма значений:

# %%
data = data.resample('1H').sum()
data.head(10)
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00         124
# 2018-03-01 01:00:00          85
# 2018-03-01 02:00:00          71
# 2018-03-01 03:00:00          66
# 2018-03-01 04:00:00          43
# 2018-03-01 05:00:00           6
# 2018-03-01 06:00:00          12
# 2018-03-01 07:00:00          15
# 2018-03-01 08:00:00          34
# 2018-03-01 09:00:00          69

# %% [markdown]
# Зафиксируем минимальное и максимальное значение индекса:

# %%
print('Минимальное значение индекса:', data.index.min())
print('Максимальное значение индекса:', data.index.max())
print('Количество строк:', data.shape[0])
# Out:
# Минимальное значение индекса: 2018-03-01 00:00:00
# Максимальное значение индекса: 2018-08-31 23:00:00
# Количество строк: 4416

# %% [markdown]
# **Вывод**:
# * Изначально данные о дате и времени были представлены с интервалом 10 минут
# * Согласно условию задачи, данные были преобразованы - изменен интервал до 1 часа
# * Представлены данные за временной промежуток:
#   * Минимальное значение: **2018-03-01 00:00:00**
#   * Максимальное значение: **2018-08-31 23:00:00**
#   * Иными словами, данные за 6 месяцев 2018 года с март по август
# * Количество строк сократилось:
#   * изначальное значение - 26496
#   * текущее значение - 4416

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ### Признак `num_orders`
# Отобразим описательную информацию:

# %%
stat_num(data, 'num_orders')
# Out:
# Описательная информация для признака 'num_orders':
# Минимальное значение: 0.0 	|	Максимальное значение: 462.0
# Среднее значение: 84.42
# Медиана: 78.0
# Межквартильный размах IQR: 53.0
# Границы нормальных значений: от 0.0 до 186.5

# %% [markdown]
# Среднее значение и медиана не сильно отличаются друг от друга. Есть значения выше границы нормальных значений:

# %%
iqr = data['num_orders'].quantile(0.75) - data['num_orders'].quantile(0.25)
upper_whisker = data['num_orders'].quantile(0.75) + 1.5 * iqr
outliers = data[data['num_orders'] > upper_whisker].shape[0]
print(f'Количество строк выходящих за верхнюю границу ({upper_whisker}) нормальных значений:', outliers)
print(f"что составляет {100 * outliers / data.shape[0]:.2f}% от всех данных")
# Out:
# Количество строк выходящих за верхнюю границу (186.5) нормальных значений: 121
# что составляет 2.74% от всех данных

# %% [markdown]
# Тем не менее, я не считаю значения выходящие за границу нормальных значений аномальными.
#
# Отобразим для признака `num_orders` скользящее среднее с размером окна 24 часа (1 день) и 1 неделя:

# %%
plt.plot(data, label="Значения признака 'num_orders'")
plt.plot(data.index, data.rolling(24).mean(), label='Скользящее среднее, размер окна: 1 день')
plt.plot(data.index, data.rolling(24*7).mean(), label='Скользящее среднее, размер окна: 1 неделя')
plt.xlabel('Временная шкала')
plt.ylabel(feature_dsc['num_orders'])
plt.title("Отображение значений признака 'num_orders', " + 
          "а также его скользящих средних значений на временной шкале")
plt.legend()
plt.show()

# %% [markdown]
# Отображение скользящего среднего позволяет снизить колебания значений или "сгладить" временной ряд. Это, в свою очередь, позволяет более наглядно оценить общую картину распределения данных.
#
# Заметно, что для наших данных среднее значение числа заказов имеет тенденцию к росту - от среднего значения около 50 заявок в час в марте, до значения стремящегося к 150 в августе.
#
# Более детально исследовать характер распределения данных временного ряда можно с помощью декомпозиции.

# %%
decomposed = seasonal_decompose(data) # декомпозиция данных

# параметры отображения графиков:
plt.figure(figsize=(15, 15))
plt.subplot(311)

# график тренда:
decomposed.trend.plot(ax=plt.gca())
plt.title('Тренд')
plt.xlabel('Временная шкала')
plt.ylabel(feature_dsc['num_orders'])
plt.subplot(312)

# график сезонной составляющей:
decomposed.seasonal.plot(ax=plt.gca())
plt.title('Сезонная составляющая')
plt.ylabel(feature_dsc['num_orders'])
plt.xlabel('Временная шкала')
plt.subplot(313)

# график остатков декомпозиции:
decomposed.resid.plot(ax=plt.gca())
plt.title('Остаток декомпозиции')
plt.ylabel(feature_dsc['num_orders'])
plt.xlabel('Временная шкала')
plt.tight_layout()

# %% [markdown]
# Отобразим график сезонной составляющей в масштабе одной недели и одного дня:

# %%
decomposed.seasonal['2018-05-01':'2018-05-07'].plot(title="Сезонная составляющая за неделю")
plt.ylabel(feature_dsc['num_orders'])
plt.xlabel('Временная шкала')
plt.show()

decomposed.seasonal['2018-05-01':'2018-05-01'].plot(title="Сезонная составляющая за день")
plt.ylabel(feature_dsc['num_orders'])
plt.xlabel('Временная шкала')
plt.show()

# %% [markdown]
# На полученном графике заметна характерная суточная сезонность числа заказов:
# * заметен пик заказов приходящийся примерно на полночь
# * спад количества заказов приходящийся на ранее утро (около 6 утра)
# * в течение дня есть два временных пика заказов - около 10:00 и около 16:00.
#
# Один из способов сделать временной ряд *стационарным*, то есть таким процессом, распределение которого со временем не меняется, это найти разности его значений:

# %%
# вычисление разностей временного ряда
data_shift = data - data.shift()

# добавление признака 'скользящее среднее значение' с окном 24 часа
data_shift['mean'] = data_shift['num_orders'].rolling(24).mean()

# добавление признака 'скользящее стандартное отклонение' с окном 24 часа
data_shift['std'] = data_shift['num_orders'].rolling(24).std()

data_shift.plot()
plt.ylabel(feature_dsc['num_orders'])
plt.xlabel('Временная шкала')
plt.title('График разности временного ряда')
plt.show()

# %% [markdown]
# Можно заметить, что среднее значение разности соседних значений признака описывается вполне линейной зависимостью.
#
# **Вывод**:
# * Признак `num_orders` содержит информацию о количестве заказов такси для соответствующей временной метки
# * Среднее значение и медиана признака не сильно отличаются и находятся в районе 80
# * 2.74% данных превышают верхнюю границу нормальных значений (186.5), тем не менее, эти данные не являются аномальными
# * Анализ скользящего среднего значения признака за весь представленный период времени показывает тенденцию к росту - от среднего значения около 50 заявок в час в марте, до значения стремящегося к 150 в августе.
# * Для признака характерна суточная сезонность числа заказов:
#   * заметен пик заказов приходящийся примерно на полночь
#   * спад количества заказов приходящийся на ранее утро (около 6 утра)
#   * в течение дня есть два временных пика заказов - около 10:00 и около 16:00.
# * Среднее значение разности соседних значений признака описывается вполне линейной зависимостью.

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ## Подготовка данных
# В процессе формирования признаков и обучения моделей мне будет более удобно работать с `datetime` как с отдельным признаком, а не индексом. Преобразую в признак:

# %%
data = data.reset_index()
data.head(2)
# Out:
#              datetime  num_orders
# 0 2018-03-01 00:00:00         124
# 1 2018-03-01 01:00:00          85

# %% [markdown]
# ### Создание новых признаков
# На данном этапе я рассмотрю добавление признаков на основе <ins>скользящего среднего</ins> и <ins>«отстающих значений»</ins>. Календарные признаки будут формироваться в пайплайне.
# #### Скользящее среднее
# Скользящее среднее как признак задаёт общий тренд временного ряда.
#
# Однако, необходимо учитывать, что скользящее среднее в моменте $t$ учитывает текущее значение ряда $x(t)$. Это некорректно: <font color='orange'>целевой признак «убежал» в признаки</font>. <font color='red'>Вычисление скользящего среднего не должно включать в себя текущее значение ряда</font>.
#
# Я добавлю два признака на основе скользящего среднего - с окном в 3 часа и с окном 24 часа.

# %%
for i in [3, 24]:
    data[f"roll_mean_{i}"] = data['num_orders'].shift().rolling(i).mean()

data.head(10)
# Out:
#              datetime  num_orders  roll_mean_3  roll_mean_24
# 0 2018-03-01 00:00:00         124          NaN           NaN
# 1 2018-03-01 01:00:00          85          NaN           NaN
# 2 2018-03-01 02:00:00          71          NaN           NaN
# 3 2018-03-01 03:00:00          66        93.33           NaN
# 4 2018-03-01 04:00:00          43        74.00           NaN
# 5 2018-03-01 05:00:00           6        60.00           NaN
# 6 2018-03-01 06:00:00          12        38.33           NaN
# 7 2018-03-01 07:00:00          15        20.33           NaN
# 8 2018-03-01 08:00:00          34        11.00           NaN
# 9 2018-03-01 09:00:00          69        20.33           NaN

# %% [markdown]
# **Вывод**: созданы признаки для скользящего среднего с окном в 3 и 24 часа.

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### «Отстающие значения»
# Предыдущие значения временного ряда подскажут, будет ли функция $x(t)$ расти или уменьшаться.
#
# Для **определения значимости лагов** можно использовать стандартные инструменты для анализа временных рядов ACF и PACF:
# * ACF (*Auto-Correlation Function*) - функция автокорреляции;
# * PACF (*Partial Auto-Correlation*) - частичная функция автокорреляции.
#
# <blockquote>ACF измеряет степень сходства между значением временного ряда и его прошлыми значениями с разными временными лагами. Другими словами, ACF измеряет корреляцию между временными отклонениями ряда и его отставаниями на различные лаги.
#
# Корреляция, близкая к 1 или -1, указывает на сильную зависимость между значениями на различных временных точках, в то время как корреляция, близкая к 0, указывает на отсутствие зависимости.
# На практике ACF позволяет определить наличие сезонных или циклических паттернов во временном ряду.
#
# PACF похожа на функцию автокорреляции, но немного сложнее для понимания. PACF показывает прямую корреляцию между текущим значением и его прошлыми значениями с учетом временных лагов. При этом она исключает влияние промежуточных значений на эту корреляцию.
#
# Другими словами, PACF фокусируется только на непосредственном влиянии прошлых значений на текущее, игнорируя косвенное влияние, которое может идти через другие промежуточные значения.
#
# > (см.: [Прогнозирование временных рядов в Python](https://teletype.in/@pythontalk/time_series_forecasting))</blockquote>
#
# Отобразим для наших данных ACF и PACF функции с размером лага до 48 часов:

# %%
plt.figure(figsize=(15, 10))  

# График ACF
plt.subplot(211)
plot_acf(data['num_orders'], lags=48, ax=plt.gca())
plt.title('График ACF функции')
plt.xlabel('Размер лагов')
plt.ylabel('Функция автокорреляции')

# График PACF
plt.subplot(212)
plot_pacf(data['num_orders'], lags=48, ax=plt.gca(), method='ywm')
plt.title('График PACF функции')
plt.xlabel('Размер лагов')
plt.ylabel('Частичная функция автокорреляции')

plt.tight_layout()
plt.show()

# %% [markdown]
# ACF и PACF функции показывают наличие корреляции для лагов равных 1 и 24.
#
# Добавлю данные лаги в качестве новых признаков:

# %%
for i in [1, 24]:
    data[f"lag_{i}"] = data['num_orders'].shift(i)
    
data.head()
# Out:
#              datetime  num_orders  roll_mean_3  roll_mean_24  lag_1  lag_24
# 0 2018-03-01 00:00:00         124          NaN           NaN    NaN     NaN
# 1 2018-03-01 01:00:00          85          NaN           NaN 124.00     NaN
# 2 2018-03-01 02:00:00          71          NaN           NaN  85.00     NaN
# 3 2018-03-01 03:00:00          66        93.33           NaN  71.00     NaN
# 4 2018-03-01 04:00:00          43        74.00           NaN  66.00     NaN

# %% [markdown]
# **Вывод**: созданы признаки с величиной лагов 1 и 24.

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ### Формирование выборок
# Для начала зададим переменные с обучающими и целевым признаками:

# %%
X = data.drop('num_orders', axis=1)
y = data['num_orders']

# %% [markdown]
# Проверим размерность:

# %%
X.shape, y.shape
# Out:
# ((4416, 5), (4416,))

# %% [markdown]
# Разобъем данные на обучающую и тестовую выборки с использованием следующих параметров:
# * `test_size=0.1` - Размер тестовой выборки равен 10% от исходных данных - это **задано условием**.
# * `shuffle=False` - Отключение перемешивания данных. Перемешивать выборки в задаче прогнозирования временного ряда <font color='red'>нельзя</font>. Данные обучающей выборки должны предшествовать данным тестовой. Иначе тестирование модели будет некорректным: модель не должна обучаться на данных из будущего.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    shuffle=False, 
    test_size=0.1
)

# %% [markdown]
# Отобразим количество строк получившихся выборок:

# %%
X_train.shape[0], X_test.shape[0], y_train.shape[0], y_test.shape[0]
# Out:
# (3974, 442, 3974, 442)

# %% [markdown]
# **Вывод**:
# * Для данных сформированы обучающие и тестовые выборки.
# * Данные разбиты без перемешивания, то есть train- и test-выборки сформированы в хронологическом порядке.
# * Выборки делятся в пропорции <span style="border-width:2px; border-style:solid; border-color:#ddb62b; padding: 3px;">90% {обучающая}</span> + <span style="border-width:2px; border-style:solid; border-color:#d160c4; padding: 3px;">10% {тестовая}</span>

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ## Задача прогнозирования
# * Целевой признак `num_orders` - количество заказов такси.
# * В качестве метрики качества используется RMSE - это **задано условием**.
# * Также условием задачи задан порог качества - **значение метрики RMSE на тестовой выборке должно быть не больше 48**.
#
# ### Прогноз без обучения
# Спрогнозировать временные ряды *без обучения* можно двумя способами:
# * Все значения тестовой выборки предсказываются одним и тем же числом (константой). Для метрики $RMSE$ - это <abbr title="для метрики MAE - это медиана">среднее значение</abbr>.
# * Новое значение $x(t)$ прогнозируется предыдущим значением ряда, то есть $x(t–1)$. Этот способ не зависит от метрики.
# #### Прогноз константой
# Рассчитаем среднее число заказов для test-выборки:

# %%
test_mean = y_test.mean()
test_mean
# Out:
# 139.55656108597285

# %% [markdown]
# Сделаем предсказания средним значением по train-выборке:

# %%
pred_mean = np.ones(y_test.shape) * y_train.mean()

# %% [markdown]
# Рассчитаем метрику RMSE:

# %%
rmse_mean = mean_squared_error(y_test, pred_mean, squared=False)
print(f"RMSE: {rmse_mean:.2f}")
print(f"Величина ошибки: {100 * rmse_mean / test_mean:.2f}%")
# Out:
# RMSE: 84.74
# Величина ошибки: 60.72%

# %% [markdown]
# **Вывод**:
# * При прогнозе значения константой - средним значением обучающей выборки - RMSE составляет 84.74, что дает погрешность 60.72%
# * Прогноз константой дает плохой результат в данном случае.

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### Прогноз предыдущим значением ряда
# Сформируем прогноз значений на основе предыдущих значений временного ряда:

# %%
pred_previous = y_test.shift()
pred_previous.iloc[0] = y_train.iloc[-1]

# %% [markdown]
# Рассчитаем метрику RMSE:

# %%
rmse_previous = mean_squared_error(y_test, pred_previous, squared=False)
print(f"RMSE: {rmse_previous:.2f}")
print(f"Величина ошибки: {100 * rmse_previous / test_mean:.2f}%")
# Out:
# RMSE: 58.86
# Величина ошибки: 42.17%

# %% [markdown]
# **Вывод:**
# * При прогнозе предыдущим значением ряда метрика RMSE улучшилась и составляет 58.86, что 42.17% от среднего значения тестовой выборки.
# * Качество прогноза *предыдущим значением* не удовлетворяет условию задания: <font color='red'>58.86 > 48</font>.

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ### Прогноз с помощью моделей МО
# #### Формирование пайплайна
# Для начала я задам функцию для извлечения признаков из `datetime` со следущим алгоритмом:
# 1. Функция получает на вход датасет с признаком `datetime`.
# 2. Функция формирует норвые календарные признаки на основе признака `datetime`:
#   * `month` - Возвращает месяц из даты.
#   * `day` - День месяца (1-31).
#   * `day_of_week` - День недели (0 - понедельник, 6 - воскресенье).
#   * `is_weekend` - Является ли день выходным (суббота/воскресенье).
#   * `hour` - Возвращает час (0-23).
# 3. Функция возвращает датасет с набором сформированных признаков, исключая сам `datetime`.

# %%
def extract_time_features(df):
    df = df.copy()
    df['month'] = df['datetime'].dt.month
    df['day'] = df['datetime'].dt.day
    df['day_of_week'] = df['datetime'].dt.dayofweek
    df['is_weekend'] = df['day_of_week'].isin([5, 6]).astype(int)
    df['hour'] = df['datetime'].dt.hour
           
    return df.drop('datetime', axis=1)

# %% [markdown]
# Сформируем препроцессор для подготовки признаков:
# * Обработка данных осуществляется с помощью **FunctionTransformer** - это класс в scikit-learn, который позволяет обернуть произвольную функцию Python в объект, совместимый с пайплайнами sklearn.
# * FunctionTransformer получает в качестве аргументов:
#   * заданную функцию для извлечения календарных признаков - `extract_time_features`
#   * `['datetime']` - признак, который нужно передать (передается не весь набор признаков, а только `datetime`)
#   * `validate=False` - булевый параметр, [определяющий, нужно ли проверять входные данные](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.FunctionTransformer.html).
# * `remainder='passthrough'` - означает, что остальные признаки (`roll_mean_3`, `roll_mean_24`, `lag_1`, `lag_24`) остаются без изменений.

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('time_features', FunctionTransformer(extract_time_features, validate=False), ['datetime'])
    ],
    remainder='passthrough'
)

# %% [markdown]
# Проверим корректность работы препроцессора:

# %%
pd.DataFrame(preprocessor.fit_transform(X_train), 
             columns=['month', 'day', 'day_of_week', 'is_weekend', 'hour', 
                      'roll_mean_3', 'roll_mean_24', 'lag_1', 'lag_24']).head(10)
# Out:
#    month  day  day_of_week  is_weekend  hour  roll_mean_3  roll_mean_24  \
# 0   3.00 1.00         3.00        0.00  0.00          NaN           NaN
# 1   3.00 1.00         3.00        0.00  1.00          NaN           NaN
# 2   3.00 1.00         3.00        0.00  2.00          NaN           NaN
# 3   3.00 1.00         3.00        0.00  3.00        93.33           NaN
# 4   3.00 1.00         3.00        0.00  4.00        74.00           NaN
# 5   3.00 1.00         3.00        0.00  5.00        60.00           NaN
# 6   3.00 1.00         3.00        0.00  6.00        38.33           NaN
# 7   3.00 1.00         3.00        0.00  7.00        20.33           NaN
# 8   3.00 1.00         3.00        0.00  8.00        11.00           NaN
# 9   3.00 1.00         3.00        0.00  9.00        20.33           NaN
#
#    lag_1  lag_24
# 0    NaN     NaN
# 1 124.00     NaN
# 2  85.00     NaN
# 3  71.00     NaN
# 4  66.00     NaN
# 5  43.00     NaN
# 6   6.00     NaN
# 7  12.00     NaN
# ...

# %% [markdown]
# Все корректно, на основе признака `datetime` формируются календарные признаки, сам признак признака `datetime` исключается из данных, а остальные признаки датасета остаются без изменений.
#
# Создадим итоговый пайплайн: подготовка данных и модель. В качестве модели по умолчанию - DecisionTreeRegressor:

# %%
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),  # Извлечение признаков из datetime
    ('models', DecisionTreeRegressor(random_state=RANDOM_STATE))  # Модель дерева решений
])

# %% [markdown]
# Создаем сетку, содержающую набор моделей и их гиперпараметров.
#
# Исследуются модели:
#
# Название модели|Гиперпараметры
# -|:-
# DecisionTreeRegressor|max_depth: [2,10]<br>min_samples_split: [2,14]
# LGBMRegressor|n_estimators: [2, 100]
# CatBoostRegressor|iterations: [100, 500]
#
# Выбор моделей обусловлен:
# * качеством моделей;
# * скоростью обучения;
# * способностью работать с пропусками "из коробки";
# * нечувствительностью к масштабам признака.

# %% [markdown]
# <div style="border:solid orange 2px; padding: 20px">
# <font color='red'>*</font> <i>Примечание</i>: значения гиперпаметров получены путем перебора значений для каждой модели и выбора из всех значений некой комбинации <ins>обеспечивающей значение метрики выше порога, заданного условием проекта</ins>. Для финальной сетки оставил небольшое число вариаций с целью сократить время на обучения модели.

# %%
# Определение сетки гиперпараметров для перебора
param_grid = [
        # Словарь для модели DecisionTreeRegressor
    {
        'models': [DecisionTreeRegressor(random_state=RANDOM_STATE, max_features=None, min_samples_leaf=6)],
        'models__max_depth': [2, 10],         
        'models__min_samples_split': [2, 14, 16],
    },

        # Словарь для модели LGBMRegressor
    {
        'models': [LGBMRegressor(random_state=RANDOM_STATE, learning_rate=0.1, max_depth=7, num_leaves=10)],
        'models__n_estimators': [2, 100]
    },  

    # Словарь для модели CatBoostRegressor
    {
        'models': [CatBoostRegressor(random_seed=RANDOM_STATE, iterations=500, verbose=0)],
        'models__learning_rate': [0.05, 1],
        'models__depth': [2, 4],
    }    
     
]

# %% [markdown]
# Создаем пайплайн с применением автоматизированного поиска гиперпараметров **GridSearchCV** со следующими параметрами:
# * Установка модели пайплайна по умолчанию `pipe_final`.
# * Применение заданной сетки гиперпараметров моделей `param_grid`.
# * `cv=tscv` - применяется кросс-валидация **TimeSeriesSplit**. Поскольку **в задачах временных рядов данные не могут быть произвольно перемешаны**, применяется специальная кросс-валидация, где данные делятся на блоки с учётом хронологического порядка.<br>Схематично это можно отобразить так:
# ![svg image](data:image/svg+xml,%3Csvg%20xmlns%3D%22http%3A//www.w3.org/2000/svg%22%20width%3D%22610%22%20height%3D%22180%22%3E%20%20%20%20%0A%20%20%3Ctext%20x%3D%223%22%20y%3D%2230%22%20font-size%3D%2216%22%20font-family%3D%22Arial%22%3E%D0%98%D1%82%D0%B5%D1%80%D0%B0%D1%86%D0%B8%D1%8F%201%3C/text%3E%0A%20%20%3Crect%20x%3D%22200%22%20y%3D%220%22%20width%3D%22200%22%20height%3D%2250%22%20%20style%3D%22fill%3Aorange%3B%20%20%22%20/%3E%0A%20%20%3Crect%20x%3D%22100%22%20y%3D%220%22%20width%3D%22200%22%20height%3D%2250%22%20%20style%3D%22fill%3A%23a7f4a6ff%3B%20%22%20/%3E%20%20%0A%20%20%3Crect%20x%3D%22400%22%20y%3D%220%22%20width%3D%22200%22%20height%3D%2250%22%20%20style%3D%22fill%3A%23eaf4f9%3B%20%22%20/%3E%20%20%0A%20%20%3Cline%20x1%3D%22300%22%20y1%3D%220%22%20x2%3D%22300%22%20y2%3D%2250%22%20stroke%3D%22black%22%20stroke-width%3D%221.5%22/%3E%0A%20%20%3Cline%20x1%3D%22400%22%20y1%3D%220%22%20x2%3D%22400%22%20y2%3D%2250%22%20stroke%3D%22black%22%20stroke-width%3D%221.5%22/%3E%20%20%0A%20%20%3Ctext%20x%3D%22180%22%20y%3D%2230%22%20font-size%3D%2216%22%20font-family%3D%22Arial%22%3ETrain%3C/text%3E%0A%20%20%3Ctext%20x%3D%22335%22%20y%3D%2230%22%20font-size%3D%2216%22%20font-family%3D%22Arial%22%3ETest%3C/text%3E%0A%20%20%3Ctext%20x%3D%223%22%20y%3D%2290%22%20font-size%3D%2216%22%20font-family%3D%22Arial%22%3E%D0%98%D1%82%D0%B5%D1%80%D0%B0%D1%86%D0%B8%D1%8F%202%3C/text%3E%0A%20%20%3Crect%20x%3D%22100%22%20y%3D%2260%22%20width%3D%22500%22%20height%3D%2250%22%20%20style%3D%22fill%3A%23a7f4a6ff%3B%20%20%22%20/%3E%0A%20%20%3Crect%20x%3D%22400%22%20y%3D%2260%22%20width%3D%22100%22%20height%3D%2250%22%20%20style%3D%22fill%3Aorange%3B%20%22%20/%3E%20%20%0A%20%20%3Crect%20x%3D%22500%22%20y%3D%2260%22%20width%3D%22100%22%20height%3D%2250%22%20%20style%3D%22fill%3A%23eaf4f9%3B%20%22%20/%3E%20%20%20%20%0A%20%20%3Cline%20x1%3D%22400%22%20y1%3D%2260%22%20x2%3D%22400%22%20y2%3D%22110%22%20stroke%3D%22black%22%20stroke-width%3D%222%22/%3E%0A%20%20%3Cline%20x1%3D%22500%22%20y1%3D%2260%22%20x2%3D%22500%22%20y2%3D%22110%22%20stroke%3D%22black%22%20stroke-width%3D%222%22/%3E%0A%20%20%3Ctext%20x%3D%22235%22%20y%3D%2290%22%20font-size%3D%2216%22%20font-family%3D%22Arial%22%3ETrain%3C/text%3E%0A%20%20%3Ctext%20x%3D%22435%22%20y%3D%2290%22%20font-size%3D%2216%22%20font-family%3D%22Arial%22%3ETest%3C/text%3E%0A%20%20%3Ctext%20x%3D%223%22%20y%3D%22150%22%20font-size%3D%2216%22%20font-family%3D%22Arial%22%3E%D0%98%D1%82%D0%B5%D1%80%D0%B0%D1%86%D0%B8%D1%8F%203%3C/text%3E%0A%20%20%3Crect%20x%3D%22100%22%20y%3D%22120%22%20width%3D%22500%22%20height%3D%2250%22%20%20style%3D%22fill%3A%23a7f4a6ff%3B%20%20%22%20/%3E%0A%20%20%3Crect%20x%3D%22500%22%20y%3D%22120%22%20width%3D%22100%22%20height%3D%2250%22%20%20style%3D%22fill%3Aorange%3B%20%22%20/%3E%20%20%20%20%0A%20%20%3Cline%20x1%3D%22500%22%20y1%3D%22120%22%20x2%3D%22500%22%20y2%3D%22170%22%20stroke%3D%22black%22%20stroke-width%3D%222%22/%3E%20%20%0A%20%20%3Ctext%20x%3D%22290%22%20y%3D%22150%22%20font-size%3D%2216%22%20font-family%3D%22Arial%22%3ETrain%3C/text%3E%0A%20%20%3Ctext%20x%3D%22535%22%20y%3D%22150%22%20font-size%3D%2216%22%20font-family%3D%22Arial%22%3ETest%3C/text%3E%0A%20%20%3Crect%20x%3D%22100%22%20y%3D%221%22%20width%3D%22500%22%20height%3D%2250%22%20style%3D%22fill%3Anone%3B%20stroke-width%3A1.25%3B%20stroke%3A%23000%3B%22%20%20/%3E%0A%20%20%3Crect%20x%3D%22100%22%20y%3D%2260%22%20width%3D%22500%22%20height%3D%2250%22%20style%3D%22fill%3Anone%3B%20stroke-width%3A1.25%3B%20stroke%3A%23000%3B%22%20%20/%3E%0A%20%20%3Crect%20x%3D%22100%22%20y%3D%22120%22%20width%3D%22500%22%20height%3D%2250%22%20style%3D%22fill%3Anone%3B%20stroke-width%3A1.25%3B%20stroke%3A%23000%3B%22%20%20/%3E%20%0A%3C/svg%3E)
#
# Дополнительная информация по кросс-валидации временных рядов:
#   * scikit-learn: Машинное обучение в Python - [Кросс-валидация данных временных рядов](https://scikit-learn.ru/stable/modules/cross_validation.html#timeseries-cv)
#   * Яндекс Образование: Учебник по машинному обучению - [Временные ряды: Кросс-валидация для временных рядов](https://education.yandex.ru/handbook/ml/article/vremennye-ryady)
#
# Я использую кросс-валидацию из 3 блоков:

# %%
# Настройка временной кросс-валидации
tscv = TimeSeriesSplit(n_splits=3)

# %% [markdown]
# * `scoring='neg_root_mean_squared_error'` - в качестве метрики качества моделей используется RMSE.
# * `verbose=0` - опция логирования процесса поиска, например:
#   * 0: Без вывода.
#   * 1: Краткий прогресс.
#   * 2+: Подробный прогресс по каждому фолду и кандидату.
# * `n_jobs=-1` - количество вычислительных мощностей (чтобы считалось быстрее, указывают `-1`)

# %%
# Настройка GridSearchCV
grid_search = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    cv=tscv,  # Временная кросс-валидация
    scoring='neg_root_mean_squared_error',  # Метрика RMSE (отрицательная для максимизации)
    verbose=0,
    n_jobs=-1
)

# %% [markdown]
# **Вывод**: сформирован пайплайн с применением автоматизированного поиска гиперпараметров **GridSearchCV**

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### Обучение моделей
# Запускаем пайплайн на тренировочных данных:

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('time_features',
#                                                                          FunctionTransformer(func=<function extract_time_features at 0x7f86c4b071f0>),
#                                                                          ['datetime'])])),
#                                        ('models',
#                                         DecisionTreeRegressor(random_state=42))]),
#              n_jobs=-1,
#              param_grid=[{'models': [DecisionTreeRegressor(min_samples_leaf=6,
#                                                            random_state=42)],
#                           'models__max_depth': [2, 10],
# ...

# %% [markdown]
# Отобразим полученные результаты:

# %%
result = show_gs_result(grid_search, 10)
result.style
# Out:
# <style  type="text/css" >
# </style><table id="T_5904e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rank_test_score</th>        <th class="col_heading level0 col1" >param_models</th>        <th class="col_heading level0 col2" >mean_test_score</th>        <th class="col_heading level0 col3" >mean_fit_time</th>        <th class="col_heading level0 col4" >params</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5904e_level0_row0" class="row_heading level0 row0" >10</th>
#                         <td id="T_5904e_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_5904e_row0_col1" class="data row0 col1" >CatBoostRegressor</td>
#                         <td id="T_5904e_row0_col2" class="data row0 col2" >26.014688</td>
#                         <td id="T_5904e_row0_col3" class="data row0 col3" >0.902431</td>
# ...

# %% [markdown]
# **Вывод**:
# * С помощью инструмента GridSearchCV обучено 3 наименования моделей с различными гиперпараметрами.
# * Все представленные варианты моделей показали приемлемую метрику качества на кросс-валидации ($RMSE ≤ 48$).

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### Анализ моделей
# Отобразим лучшие результаты исследуемых наименований моделей:

# %%
best_scores = (result.loc[result.groupby('param_models')['mean_test_score'].idxmin()]
               .sort_values(by='rank_test_score'))
best_scores.style.format({col: '{:.4f}' for col in ['mean_test_score', 'mean_fit_time']})
# Out:
# <style  type="text/css" >
# </style><table id="T_71aed_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rank_test_score</th>        <th class="col_heading level0 col1" >param_models</th>        <th class="col_heading level0 col2" >mean_test_score</th>        <th class="col_heading level0 col3" >mean_fit_time</th>        <th class="col_heading level0 col4" >params</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_71aed_level0_row0" class="row_heading level0 row0" >7</th>
#                         <td id="T_71aed_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_71aed_row0_col1" class="data row0 col1" >CatBoostRegressor</td>
#                         <td id="T_71aed_row0_col2" class="data row0 col2" >26.0147</td>
#                         <td id="T_71aed_row0_col3" class="data row0 col3" >0.9210</td>
# ...

# %% [markdown]
# Отобразим характеристики с помощью графиков

# %%
models_compare(best_scores)

# %% [markdown]
# **Вывод**:
# * Модель **CatBoostRegressor** лидирует по качеству метрики RMSE=26.0147
# * Модель DecisionTreeRegressor имеет менее низкую метрику: RMSE=30.2887, но все еще приемлемую по условию. При этом время обучения почти в 100 раз быстрее чем у лидера, что можно отнести к достоинству.
# * Модель LGBMRegressor по метрике ближе CatBoostRegressor, но время обучения в 5 раз (цифра и характер различия меняются от запуска к запуску 🤷‍♂️) дольше чем у того же CatBoost.
# * По совокупности характеристик, лучшая из исследуемых моделей - **CatBoostRegressor**.
#
# Зададим переменную содержащую информацию о лучшей модели:

# %%
best_model = grid_search.best_estimator_

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### Оценка качества модели на тестовых данных
# Рассчитаем метрику лучшей модели на тестовых данных:

# %%
y_test_pred = best_model.predict(X_test)
rmse_test = mean_squared_error(y_test, y_test_pred, squared=False)
print(f'Метрика RMSE на тестовой выборке: {rmse_test:.2f}')
print(f"Величина ошибки: {100 * rmse_test / test_mean:.2f}%")
# Out:
# Метрика RMSE на тестовой выборке: 42.25
# Величина ошибки: 30.27%

# %% [markdown]
# **Вывод**:
# * Метрика RMSE модели **CatBoostRegressor** на тестовых данных составляет 42.25, что удовлетворяет заданному условию $RMSE ≤ 48$

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### Проверка модели на адекватность
# В пункте '[Прогноз без обучения](#Прогноз-без-обучения)' производился прогноз значений на основе константы или подстановки предыдущего значения. По сути это и есть Dummy-модель.
#
# Не буду повторять процесс заново, лишь приведу данные:

# %%
pd.DataFrame({'RMSE':[rmse_mean, rmse_previous, rmse_test],
              '%':[100 * rmse_mean / test_mean,
                   100 * rmse_previous / test_mean,
                   100 * rmse_test / test_mean]}, 
             index=['Прогноз константой','Предыдущее значение','CatBoostRegressor'])
# Out:
#                      RMSE     %
# Прогноз константой  84.74 60.72
# Предыдущее значение 58.86 42.17
# CatBoostRegressor   42.25 30.27

# %% [markdown]
# Отобразим распределения целевого признака на графике:

# %%
plt.plot(y_test.values, linewidth=3, color='b', label='Реальные значения', linestyle='-')
plt.plot(y_test_pred, linewidth=1.5, color='#00FF00', label='CatBoost')
plt.plot(pred_previous.values, linewidth=2, color='#FF00FF', label='Предыдущее значение', linestyle=':')
plt.plot(pred_mean, linewidth=2, color='r', label='Среднее', linestyle='-.')

plt.title('Сравнение прогнозов с реальными значениями', fontsize=14, pad=10)
plt.xlabel('Временные шаги')
plt.ylabel(feature_dsc['num_orders'])
plt.legend()
plt.show()

# %% [markdown]
# **Вывод**:
# * Модель **CatBoostRegressor** прошла проверку на адекватность показав метрику качества лучше, чем у предсказаний простейшими способами - прогноза константой и прогноза предыдущим значеним.

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ## Общий вывод
# Для данных предоставленных компанией «Чётенькое такси», содержащих исторические данные о заказах такси в аэропортах с поставленной целью - прогнозирование количества заказов такси на следующий час - было проведено исследование, в рамках которого:
# 1. Произведено предварительное изучение данных:
# * Проверена корректность и соответствие предоставленных данных заявленным заказчиком
# * Проведена предварительная обработка данных:
#   * данные проверены на наличие пропусков, дубликатов, а также на соответствие типов признаков на подходящие для решения задачи:
#     * признак `datetime` приведен к формату `datetime` и установлен в качестве индекса
# 2. Проведен анализ данных:
# * Согласно условию задания, произведено ресемплирование данных с частоты 10 минут до частоты 1 час
# * Анализ проводится на основании имеющихся в распоряжении данных за 6 месяцев 2018 года - с март по август
# * Исследовано распределение целевого признака:
#   * Среднее значение и медиана признака не сильно отличаются и находятся в районе 80
#   * 2.74% данных превышают верхнюю границу нормальных значений (равную 186.5), тем не менее, эти данные не являются аномальными
#   * Анализ скользящего среднего значения признака за весь представленный период времени показывает тенденцию к росту - от среднего значения около 50 заявок в час в марте, до значения стремящегося к 150 в августе.
#   * Для целевого признака характерна суточная сезонность числа заказов:
#     * заметен пик заказов приходящийся примерно на полночь
#     * спад количества заказов приходящийся на ранее утро (около 6 утра)
#     * в течение дня есть два временных пика заказов - около 10:00 и около 16:00.
#   * Среднее значение разности соседних значений признака описывается вполне линейной зависимостью.
# 3. На этапе подготовки данных
# * Созданы новые признаки:
#   * созданы признаки для скользящего среднего с окном в 3 и 24 часа.
#   * созданы признаки с величиной лагов 1 и 24.
# * Для данных сформированы обучающие и тестовые выборки:
#   * Данные разбиты без перемешивания, то есть train- и test-выборки сформированы в хронологическом порядке.
#   * Выборки делятся в пропорции <span style="border-width:2px; border-style:solid; border-color:#ddb62b; padding: 3px;">90% {обучающая}</span> + <span style="border-width:2px; border-style:solid; border-color:#d160c4; padding: 3px;">10% {тестовая}</span>
# 4. Осуществлен прогноз значений временного ряда
# * Целевой признак `num_orders` - количество заказов такси.
# * В качестве метрики качества используется RMSE.
# * Условием задачи был задан порог качества - **значение метрики RMSE на тестовой выборке должно быть не больше 48**.
# * В качестве простых моделей прогноза использованы 'прогноз константой' и 'прогноз предыдущим значением ряда'. Получены результаты:
#   * При прогнозе значения константой (средним значением обучающей выборки) - RMSE составляет 84.74, что дает погрешность 60.72%. Это неудовлетворительный результат.
#   * При прогнозе предыдущим значением ряда метрика RMSE улучшилась и составила 58.86, что 42.17% от среднего значения тестовой выборки. Но качество прогноза при этом по прежнему не удовлетворяет условию задания: 58.86 > 48.
# * При прогнозе на основе моделей машинного обучения поиск лучшей модели осуществлялся с помощью пайплайна - инструмента, который позволяет автоматизировать действия по подготовке данных, обучению моделей и оценке их качества.
#   * В пайплайн была интегрирована функция извлечения из `datetime` календарных признаков, таких как: month, day, day_of_week, is_weekend, hour.
#   * В качестве моделей рассматривались DecisionTreeRegressor, LGBMRegressor, CatBoostRegressor
#   * Выбор моделей обусловлен:
#     * качеством моделей;
#     * скоростью обучения;
#     * способностью работать с пропусками "из коробки";
#     * нечувствительностью к масштабам признаков.
#   * С помощью инструмента GridSearchCV получено 8 обученных моделей. Все модели показали приемлемую метрику качества на кросс-валидации (RMSE≤48).
#   * По совокупности характеристик, была выбрана лучшая из исследуемых моделей - **CatBoostRegressor**, имеющая метрику качества RMSE=26.0147 на кросс-валидации
#   * Метрика RMSE модели CatBoostRegressor на тестовых данных составила 42.25, что удовлетворяет заданному условию.
#   * Модель CatBoostRegressor прошла проверку на адекватность показав метрику качества лучше, чем у предсказаний простейшими способами - прогноза константой и прогноза предыдущим значеним.

# %% [markdown]
# [Вернуться к оглавлению](#point0)
