# %% [markdown]
# # Проект: Обучение с учителем: качество модели

# %% [markdown]
# <a id="point0"></a>
# # Оглавление
#
# * [1 Загрузка и изучение данных](#Загрузка-и-изучение-данных)
#   * [1.1 Загрузка данных](#Загрузка-данных)
#   * [1.2 Изучение данных](#Изучение-данных)
# * [2 Предобработка данных](#Предобработка-данных)
#   * [2.1 Переименование столбцов](#Переименование-столбцов)
#   * [2.2 Обработка пропусков](#Обработка-пропусков)
#   * [2.3 Изменение типов данных](#Изменение-типов-данных)
#   * [2.4 Обработка дубликатов](#Обработка-дубликатов)
#   * [2.4.1 Обработка неявных дубликатов](#Обработка-неявных-дубликатов)
#   * [2.4.2 Обработка явных дубликатов](#Обработка-явных-дубликатов)
# * [3 Исследовательский анализ данных](#Исследовательский-анализ-данных)
#   * [3.1 Анализ количественных признаков](#Анализ-количественных-признаков)
#    * [3.1.1 Признак "Маркет_актив\_6\_мес"](#Признак-Маркет_актив_6_мес)
#    * [3.1.2 Признак "Маркет_актив_тек_мес"](#Признак-&quot;Маркет_актив_тек_мес&quot;)
#    * [3.1.3 Признак "Длительность"](#Признак-&quot;Длительность&quot;)
#    * [3.1.4 Признак "Акционные_покупки"](#Признак-&quot;Акционные_покупки&quot;)
#    * [3.1.5 Признак "Средний_просмотр_категорий_за_визит"](#Признак-&quot;Средний_просмотр_категорий_за_визит&quot;)
#    * [3.1.6 Признак "Неоплаченные_продукты_штук_квартал"](#Признак-&quot;Неоплаченные_продукты_штук_квартал&quot;)
#    * [3.1.7 Признак "Ошибка_сервиса"](#Признак-&quot;Ошибка_сервиса&quot;)
#    * [3.1.8 Признак "Страниц_за_визит"](#Признак-&quot;Страниц_за_визит&quot;)
#    * [3.1.9 Признак "Выручка"](#Признак-&quot;Выручка&quot;)
#    * [3.1.10 Признак "Минут"](#Признак-&quot;минут&quot;)
#    * [3.1.11 Признак "Прибыль"](#Признак-&quot;Прибыль&quot;)
#   * [3.2 Анализ категориальных признаков](#Анализ-категориальных-признаков)
#    * [3.2.1 Признак "Покупательская_активность" (целевой признак)](#Признак-&quot;Покупательская_активность&quot;-(целевой-признак))
#    * [3.2.2 Признак "Тип_сервиса"](#Признак-&quot;Тип_сервиса&quot;)
#    * [3.2.3 Признак "Разрешить_сообщать"](#Признак-&quot;Разрешить_сообщать&quot;)
#    * [3.2.4 Признак "Популярная_категория"](#Признак-&quot;Популярная_категория&quot;)
#    * [3.2.5 Признак "Период" (market_money)](#Признак-&quot;Период&quot;-(market_money))
#    * [3.2.6 Признак "Период" (market_time)](#Признак-&quot;Период&quot;-(market_time))
#    * [3.3 Отбор клиентов с покупательской активностью не менее трёх месяцев](#Отбор-клиентов-с-покупательской-активностью-не-менее-трёх-месяцев)
# * [4 Объединение таблиц](#Объединение-таблиц)
# * [5 Корреляционный анализ](#Корреляционный-анализ)
# * [6 Использование пайплайнов](#Использование-пайплайнов)
# * [7 Анализ важности признаков](#Анализ-важности-признаков)
# * [8 Сегментация покупателей](#Сегментация-покупателей)
#   * [8.1 Первый сегмент](#Первый-сегмент)
#   * [8.2 Второй сегмент](#Второй-сегмент)
# * [9 Общий вывод](#Общий-вывод)

# %% [markdown]
# # Описание проекта
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.
# «В один клик» — современная компания, поэтому её руководство не хочет принимать решения просто так — только на основе анализа данных и бизнес-моделирования. У компании есть небольшой отдел цифровых технологий, и вам предстоит побыть в роли стажёра в этом отделе.
# Итак, вашему отделу поручили разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.
#
# # Как решать задачу
# Продумывать подход к решению этой задачи вам не придётся — руководитель отдела его уже сформировал:
# 1. Нужно промаркировать уровень финансовой активности постоянных покупателей. В компании принято выделять два уровня активности: «снизилась», если клиент стал покупать меньше товаров, и «прежний уровень».
# 2. Нужно собрать данные по клиентам по следующим группам:
#  * Признаки, которые описывают коммуникацию сотрудников компании с клиентом.
#  * Признаки, которые описывают продуктовое поведение покупателя. Например, какие товары покупает и как часто.
#  * Признаки, которые описывают покупательское поведение клиента. Например, сколько тратил в магазине.
#  * Признаки, которые описывают поведение покупателя на сайте. Например, как много страниц просматривает и сколько времени проводит на сайте.
#
# Представим группы признаков (вместе с целевым) в виде диаграммы — такую визуализацию ещё называют <abbr title="Визуальный метод анализа причинно-следственных связей, популярный в управлении бизнесом. Диаграмма названа в честь профессора Токийского университета Каору Исикава. Из-за внешнего вида диаграмму иногда называют «рыбий скелет» или «рыбья кость» (англ. fishbone diagram).">диаграммой Исикавы</abbr>.

# %% [markdown]
# ![svg image](data:image/svg+xml,%3Csvg%20xmlns%3D%22http%3A//www.w3.org/2000/svg%22%20width%3D%22900%22%20height%3D%22690%22%3E%0A%20%20%20%20%3Crect%20x%3D%22307%22%20y%3D%221%22%20width%3D%22204%22%20height%3D%2248%22%20rx%3D%2210%22%20style%3D%22fill%3A%23f0d4f9%3B%20stroke%3Ablack%3B%22%20/%3E%0A%20%20%20%20%3Ctext%20x%3D%22325%22%20y%3D%2230%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%9A%D0%BE%D0%BC%D0%BC%D1%83%D0%BD%D0%B8%D0%BA%D0%B0%D1%86%D0%B8%D1%8F%20%D1%81%20%D0%BA%D0%BB%D0%B8%D0%B5%D0%BD%D1%82%D0%BE%D0%BC%3C/text%3E%0A%0A%20%20%20%20%3Crect%20x%3D%22608%22%20y%3D%221%22%20width%3D%22204%22%20height%3D%2248%22%20rx%3D%2210%22%20style%3D%22fill%3A%23ccefdd%3B%20stroke%3Ablack%3B%22%20/%3E%0A%20%20%20%20%3Ctext%20x%3D%22632%22%20y%3D%2230%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%9F%D1%80%D0%BE%D0%B4%D1%83%D0%BA%D1%82%D0%BE%D0%B2%D0%BE%D0%B5%20%D0%BF%D0%BE%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D0%B5%3C/text%3E%0A%0A%20%20%20%20%3Crect%20x%3D%22404%22%20y%3D%2290%22%20width%3D%22204%22%20height%3D%2236%22%20rx%3D%2210%22%20stroke-width%3D%221.5%22%20style%3D%22fill%3A%23fff%3B%20stroke%3A%23cc71ea%3B%22%20%20/%3E%0A%20%20%20%20%3Ctext%20x%3D%22470%22%20y%3D%22113%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%A2%D0%B8%D0%BF%20%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D0%B0%3C/text%3E%0A%20%20%20%20%3Cline%20x1%3D%22383%22%20y1%3D%22108%22%20x2%3D%22404%22%20y2%3D%22108%22%20stroke%3D%22black%22%20/%3E%0A%0A%20%20%20%20%3Crect%20x%3D%22385%22%20y%3D%22132%22%20width%3D%22204%22%20height%3D%2236%22%20rx%3D%2210%22%20stroke-width%3D%221.5%22%20style%3D%22fill%3A%23fff%3B%20stroke%3A%23cc71ea%3B%22%20%20/%3E%0A%20%20%20%20%3Ctext%20x%3D%22400%22%20y%3D%22155%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%A0%D0%B0%D0%B7%D1%80%D0%B5%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BD%D0%B0%20%D1%81%D0%BE%D0%BE%D0%B1%D1%89%D0%B5%D0%BD%D0%B8%D1%8F%3C/text%3E%0A%20%20%20%20%3Cline%20x1%3D%22364%22%20y1%3D%22151%22%20x2%3D%22385%22%20y2%3D%22151%22%20stroke%3D%22black%22%20/%3E%0A%0A%20%20%20%20%3Crect%20x%3D%22366%22%20y%3D%22175%22%20width%3D%22204%22%20height%3D%2236%22%20rx%3D%2210%22%20stroke-width%3D%221.5%22%20style%3D%22fill%3A%23fff%3B%20stroke%3A%23cc71ea%3B%22%20%20/%3E%0A%20%20%20%20%3Ctext%20x%3D%22400%22%20y%3D%22198%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%9C%D0%B0%D1%80%D0%BA%D0%B5%D1%82%D0%B8%D0%BD%D0%B3%206%20%D0%BC%D0%B5%D1%81%D1%8F%D1%86%D0%B5%D0%B2%3C/text%3E%0A%20%20%20%20%3Cline%20x1%3D%22345%22%20y1%3D%22194%22%20x2%3D%22366%22%20y2%3D%22194%22%20stroke%3D%22black%22%20/%3E%0A%0A%20%20%20%20%3Crect%20x%3D%22348%22%20y%3D%22218%22%20width%3D%22204%22%20height%3D%2236%22%20rx%3D%2210%22%20stroke-width%3D%221.5%22%20style%3D%22fill%3A%23fff%3B%20stroke%3A%23cc71ea%3B%22%20%20/%3E%0A%20%20%20%20%3Ctext%20x%3D%22360%22%20y%3D%22241%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%9C%D0%B0%D1%80%D0%BA%D0%B5%D1%82%D0%B8%D0%BD%D0%B3%20%D1%82%D0%B5%D0%BA%D1%83%D1%89%D0%B5%D0%B3%D0%BE%20%D0%BC%D0%B5%D1%81%D1%8F%D1%86%D0%B0%3C/text%3E%0A%20%20%20%20%3Cline%20x1%3D%22327%22%20y1%3D%22237%22%20x2%3D%22348%22%20y2%3D%22237%22%20stroke%3D%22black%22%20/%3E%0A%0A%20%20%20%20%3Crect%20x%3D%22329%22%20y%3D%22261%22%20width%3D%22204%22%20height%3D%2236%22%20rx%3D%2210%22%20stroke-width%3D%221.5%22%20style%3D%22fill%3A%23fff%3B%20stroke%3A%23cc71ea%3B%22%20%20/%3E%0A%20%20%20%20%3Ctext%20x%3D%22390%22%20y%3D%22274%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%94%D0%BB%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D0%BE%D1%81%D1%82%D1%8C%3C/text%3E%0A%20%20%20%20%3Ctext%20x%3D%22370%22%20y%3D%22292%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%B8%D1%81%D1%82%D0%BE%D1%80%D0%B8%D0%B8%20%D1%81%20%D0%BA%D0%BB%D0%B8%D0%B5%D0%BD%D1%82%D0%BE%D0%BC%3C/text%3E%0A%20%20%20%20%3Cline%20x1%3D%22308%22%20y1%3D%22280%22%20x2%3D%22329%22%20y2%3D%22280%22%20stroke%3D%22black%22%20/%3E%0A%0A%20%20%20%20%3Cline%20x1%3D%22409%22%20y1%3D%2249%22%20x2%3D%22282%22%20y2%3D%22338%22%20stroke%3D%22black%22%20/%3E%0A%20%20%20%20%3Cline%20x1%3D%22584%22%20y1%3D%22338%22%20x2%3D%22710%22%20y2%3D%2249%22%20stroke%3D%22black%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%3Cline%20x1%3D%22203%22%20y1%3D%22338%22%20x2%3D%22584%22%20y2%3D%22338%22%20stroke%3D%22black%22%20/%3E%0A%20%20%20%20%3Cline%20x1%3D%22203%22%20y1%3D%22350%22%20x2%3D%22584%22%20y2%3D%22350%22%20stroke%3D%22black%22%20/%3E%0A%0A%20%20%20%20%3Cline%20x1%3D%22409%22%20y1%3D%22639%22%20x2%3D%22282%22%20y2%3D%22350%22%20stroke%3D%22black%22%20/%3E%0A%20%20%20%20%3Cline%20x1%3D%22584%22%20y1%3D%22350%22%20x2%3D%22710%22%20y2%3D%22639%22%20stroke%3D%22black%22%20/%3E%0A%0A%20%20%20%20%3Crect%20x%3D%221%22%20y%3D%22314%22%20width%3D%22203%22%20height%3D%2260%22%20rx%3D%2210%22%20style%3D%22fill%3A%23fff%3B%20stroke%3A%23000%3B%22%20%20/%3E%0A%20%20%20%20%3Ctext%20x%3D%224%22%20y%3D%22340%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%A3%D1%80%D0%BE%D0%B2%D0%B5%D0%BD%D1%8C%20%D1%81%D0%BD%D0%B8%D0%B6%D0%B5%D0%BD%D0%B8%D1%8F%20%D0%B0%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D0%BE%D1%81%D1%82%D0%B8%3C/text%3E%0A%20%20%20%20%3Ctext%20x%3D%2225%22%20y%3D%22360%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%B2%20%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D1%8E%D1%89%D0%B8%D0%B5%203%20%D0%BC%D0%B5%D1%81%D1%8F%D1%86%D0%B0%3C/text%3E%0A%0A%20%20%20%20%3Crect%20x%3D%22696%22%20y%3D%2298%22%20width%3D%22203%22%20height%3D%2259%22%20rx%3D%2210%22%20stroke-width%3D%221.5%22%20style%3D%22fill%3A%23fff%3B%20stroke%3A%2300a949%3B%22%20%20/%3E%0A%20%20%20%20%3Ctext%20x%3D%22710%22%20y%3D%22122%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%9D%D0%B0%D0%B8%D0%B1%D0%BE%D0%BB%D0%B5%D0%B5%20%D1%87%D0%B0%D1%81%D1%82%D0%B0%D1%8F%20%D0%BA%D0%B0%D1%82%D0%B5%D0%B3%D0%BE%D1%80%D0%B8%D1%8F%3C/text%3E%0A%20%20%20%20%3Ctext%20x%3D%22740%22%20y%3D%22142%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%BF%D1%80%D0%BE%D0%B4%D1%83%D0%BA%D1%82%D0%B0%20%D0%B2%20%D0%B7%D0%B0%D0%BA%D0%B0%D0%B7%D0%B5%3C/text%3E%0A%20%20%20%20%3Cline%20x1%3D%22676%22%20y1%3D%22127%22%20x2%3D%22696%22%20y2%3D%22127%22%20stroke%3D%22black%22%20/%3E%0A%0A%20%20%20%20%3Crect%20x%3D%22667%22%20y%3D%22164%22%20width%3D%22204%22%20height%3D%2259%22%20rx%3D%2210%22%20stroke-width%3D%221.5%22%20style%3D%22fill%3A%23fff%3B%20stroke%3A%2300a949%3B%22%20%20/%3E%0A%20%20%20%20%3Ctext%20x%3D%22720%22%20y%3D%22180%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%A1%D1%80%D0%B5%D0%B4%D0%BD%D0%B5%D0%B5%20%D1%87%D0%B8%D1%81%D0%BB%D0%BE%3C/text%3E%0A%20%20%20%20%3Ctext%20x%3D%22677%22%20y%3D%22198%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%BF%D1%80%D0%BE%D1%81%D0%BC%D0%B0%D1%82%D1%80%D0%B8%D0%B2%D0%B0%D0%B5%D0%BC%D1%8B%D1%85%20%D0%BA%D0%B0%D1%82%D0%B5%D0%B3%D0%BE%D1%80%D0%B8%D0%B9%3C/text%3E%0A%20%20%20%20%3Ctext%20x%3D%22710%22%20y%3D%22216%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%BF%D1%80%D0%BE%D0%B4%D1%83%D0%BA%D1%82%D0%BE%D0%B2%20%D0%B7%D0%B0%20%D0%B2%D0%B8%D0%B7%D0%B8%D1%82%3C/text%3E%0A%20%20%20%20%3Cline%20x1%3D%22647%22%20y1%3D%22194%22%20x2%3D%22667%22%20y2%3D%22194%22%20stroke%3D%22black%22%20/%3E%0A%0A%20%20%20%20%3Crect%20x%3D%22638%22%20y%3D%22230%22%20width%3D%22204%22%20height%3D%2259%22%20rx%3D%2210%22%20stroke-width%3D%221.5%22%20style%3D%22fill%3A%23fff%3B%20stroke%3A%2300a949%3B%22%20%20/%3E%0A%20%20%20%20%3Ctext%20x%3D%22675%22%20y%3D%22245%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%A7%D0%B8%D1%81%D0%BB%D0%BE%20%D0%BD%D0%B5%D0%BE%D0%BF%D0%BB%D0%B0%D1%87%D0%B5%D0%BD%D0%BD%D1%8B%D1%85%3C/text%3E%0A%20%20%20%20%3Ctext%20x%3D%22680%22%20y%3D%22263%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%BF%D1%80%D0%BE%D0%B4%D1%83%D0%BA%D1%82%D0%BE%D0%B2%20%D0%B2%20%D0%BA%D0%BE%D1%80%D0%B7%D0%B8%D0%BD%D0%B5%3C/text%3E%0A%20%20%20%20%3Ctext%20x%3D%22675%22%20y%3D%22281%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%B7%D0%B0%20%D0%BF%D0%BE%D1%81%D0%BB%D0%B5%D0%B4%D0%BD%D0%B8%D0%B5%203%20%D0%BC%D0%B5%D1%81%D1%8F%D1%86%D0%B0%3C/text%3E%0A%20%20%20%20%3Cline%20x1%3D%22618%22%20y1%3D%22260%22%20x2%3D%22638%22%20y2%3D%22260%22%20stroke%3D%22black%22%20/%3E%0A%0A%20%20%20%20%3Crect%20x%3D%22307%22%20y%3D%22639%22%20width%3D%22204%22%20height%3D%2248%22%20rx%3D%2210%22%20style%3D%22fill%3A%23cce8ff%3B%20stroke%3Ablack%3B%22%20/%3E%0A%20%20%20%20%3Ctext%20x%3D%22340%22%20y%3D%22668%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%9F%D0%BE%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BD%D0%B0%20%D1%81%D0%B0%D0%B9%D1%82%D0%B5%3C/text%3E%0A%0A%20%20%20%20%3Crect%20x%3D%22608%22%20y%3D%22639%22%20width%3D%22204%22%20height%3D%2248%22%20rx%3D%2210%22%20style%3D%22fill%3A%23ffe7e4%3B%20stroke%3Ablack%3B%22%20/%3E%0A%20%20%20%20%3Ctext%20x%3D%22632%22%20y%3D%22668%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%A4%D0%B8%D0%BD%D0%B0%D0%BD%D1%81%D0%BE%D0%B2%D0%BE%D0%B5%20%D0%BF%D0%BE%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D0%B5%3C/text%3E%0A%0A%20%20%20%20%3Crect%20x%3D%22413%22%20y%3D%22584%22%20width%3D%22204%22%20height%3D%2236%22%20rx%3D%2210%22%20stroke-width%3D%221.5%22%20style%3D%22fill%3A%23fff%3B%20stroke%3A%23007eff%3B%22%20%20/%3E%0A%20%20%20%20%3Ctext%20x%3D%22475%22%20y%3D%22607%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%A1%D0%B1%D0%BE%D0%B8%20%D1%81%D0%B0%D0%B9%D1%82%D0%B0%3C/text%3E%0A%20%20%20%20%3Cline%20x1%3D%22392%22%20y1%3D%22602%22%20x2%3D%22413%22%20y2%3D%22602%22%20stroke%3D%22black%22%20/%3E%0A%0A%20%20%20%20%3Crect%20x%3D%22394%22%20y%3D%22541%22%20width%3D%22204%22%20height%3D%2236%22%20rx%3D%2210%22%20stroke-width%3D%221.5%22%20style%3D%22fill%3A%23fff%3B%20stroke%3A%23007eff%3B%22%20%20/%3E%0A%20%20%20%20%3Ctext%20x%3D%22420%22%20y%3D%22563%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%A7%D0%B8%D1%81%D0%BB%D0%BE%20%D1%81%D1%82%D1%80%D0%B0%D0%BD%D0%B8%D1%86%20%D0%B7%D0%B0%20%D0%B2%D0%B8%D0%B7%D0%B8%D1%82%3C/text%3E%0A%20%20%20%20%3Cline%20x1%3D%22373%22%20y1%3D%22559%22%20x2%3D%22394%22%20y2%3D%22559%22%20stroke%3D%22black%22%20/%3E%0A%0A%20%20%20%20%3Crect%20x%3D%22376%22%20y%3D%22498%22%20width%3D%22204%22%20height%3D%2236%22%20rx%3D%2210%22%20stroke-width%3D%221.5%22%20style%3D%22fill%3A%23fff%3B%20stroke%3A%23007eff%3B%22%20%20/%3E%0A%20%20%20%20%3Ctext%20x%3D%22430%22%20y%3D%22520%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%9C%D0%B8%D0%BD%D1%83%D1%82%20%D0%B7%D0%B0%20%D0%B2%D0%B8%D0%B7%D0%B8%D1%82%3C/text%3E%0A%20%20%20%20%3Cline%20x1%3D%22355%22%20y1%3D%22516%22%20x2%3D%22376%22%20y2%3D%22516%22%20stroke%3D%22black%22%20/%3E%0A%0A%20%20%20%20%3Crect%20x%3D%22357%22%20y%3D%22455%22%20width%3D%22204%22%20height%3D%2236%22%20rx%3D%2210%22%20stroke-width%3D%221.5%22%20style%3D%22fill%3A%23fff%3B%20stroke%3A%23007eff%3B%22%20%20/%3E%0A%20%20%20%20%3Ctext%20x%3D%22410%22%20y%3D%22470%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%92%D1%80%D0%B5%D0%BC%D1%8F%20%D0%BD%D0%B0%20%D1%81%D0%B0%D0%B9%D1%82%D0%B5%3C/text%3E%0A%20%20%20%20%3Ctext%20x%3D%22405%22%20y%3D%22485%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%B7%D0%B0%20%D1%82%D0%B5%D0%BA%D1%83%D1%89%D0%B8%D0%B9%20%D0%BC%D0%B5%D1%81%D1%8F%D1%86%3C/text%3E%0A%20%20%20%20%3Cline%20x1%3D%22336%22%20y1%3D%22473%22%20x2%3D%22357%22%20y2%3D%22473%22%20stroke%3D%22black%22%20/%3E%0A%0A%20%20%20%20%3Crect%20x%3D%22338%22%20y%3D%22412%22%20width%3D%22204%22%20height%3D%2236%22%20rx%3D%2210%22%20stroke-width%3D%221.5%22%20style%3D%22fill%3A%23fff%3B%20stroke%3A%23007eff%3B%22%20%20/%3E%0A%20%20%20%20%3Ctext%20x%3D%22390%22%20y%3D%22426%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%92%D1%80%D0%B5%D0%BC%D1%8F%20%D0%BD%D0%B0%20%D1%81%D0%B0%D0%B9%D1%82%D0%B5%3C/text%3E%0A%20%20%20%20%3Ctext%20x%3D%22370%22%20y%3D%22442%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%B7%D0%B0%20%D0%BF%D1%80%D0%B5%D0%B4%D1%8B%D0%B4%D1%83%D1%89%D0%B8%D0%B9%20%D0%BC%D0%B5%D1%81%D1%8F%D1%86%3C/text%3E%0A%20%20%20%20%3Cline%20x1%3D%22317%22%20y1%3D%22430%22%20x2%3D%22338%22%20y2%3D%22430%22%20stroke%3D%22black%22%20/%3E%0A%0A%20%20%20%20%3Crect%20x%3D%22319%22%20y%3D%22369%22%20width%3D%22204%22%20height%3D%2236%22%20rx%3D%2210%22%20stroke-width%3D%221.5%22%20style%3D%22fill%3A%23fff%3B%20stroke%3A%23007eff%3B%22%20%20/%3E%0A%20%20%20%20%3Ctext%20x%3D%22370%22%20y%3D%22383%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%92%D1%80%D0%B5%D0%BC%D1%8F%20%D0%BD%D0%B0%20%D1%81%D0%B0%D0%B9%D1%82%D0%B5%3C/text%3E%0A%20%20%20%20%3Ctext%20x%3D%22370%22%20y%3D%22400%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%B7%D0%B0%20%D0%BF%D1%80%D0%BE%D1%88%D0%BB%D1%8B%D0%B9%20%D0%B3%D0%BE%D0%B4%3C/text%3E%0A%20%20%20%20%3Cline%20x1%3D%22298%22%20y1%3D%22387%22%20x2%3D%22319%22%20y2%3D%22387%22%20stroke%3D%22black%22%20/%3E%0A%0A%20%20%20%20%3Crect%20x%3D%22638%22%20y%3D%22399%22%20width%3D%22204%22%20height%3D%2259%22%20rx%3D%2210%22%20stroke-width%3D%221.5%22%20style%3D%22fill%3A%23fff%3B%20stroke%3A%23ff4528%3B%22%20%20/%3E%0A%20%20%20%20%3Ctext%20x%3D%22680%22%20y%3D%22415%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%A0%D0%B0%D0%B7%D0%BD%D0%B8%D1%86%D0%B0%20%D0%B2%20%D0%B2%D1%8B%D1%80%D1%83%D1%87%D0%BA%D0%B5%3C/text%3E%0A%20%20%20%20%3Ctext%20x%3D%22695%22%20y%3D%22433%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%BF%D1%80%D0%B5%D0%B4%D1%8B%D0%B4%D1%83%D1%89%D0%B5%D0%B3%D0%BE%3C/text%3E%0A%20%20%20%20%3Ctext%20x%3D%22650%22%20y%3D%22451%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%B8%20%D0%BF%D1%80%D0%B5%D0%B4%D0%BF%D1%80%D0%B5%D0%B4%D1%8B%D0%B4%D1%83%D1%89%D0%B5%D0%B3%D0%BE%20%D0%BC%D0%B5%D1%81%D1%8F%D1%86%D0%B0%3C/text%3E%0A%20%20%20%20%3Cline%20x1%3D%22618%22%20y1%3D%22429%22%20x2%3D%22638%22%20y2%3D%22429%22%20stroke%3D%22black%22%20/%3E%0A%0A%20%20%20%20%3Crect%20x%3D%22667%22%20y%3D%22465%22%20width%3D%22204%22%20height%3D%2259%22%20rx%3D%2210%22%20stroke-width%3D%221.5%22%20style%3D%22fill%3A%23fff%3B%20stroke%3A%23ff4528%3B%22%20%20/%3E%0A%20%20%20%20%3Ctext%20x%3D%22677%22%20y%3D%22487%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%A0%D0%B0%D0%B7%D0%BD%D0%B8%D1%86%D0%B0%20%D0%B2%20%D0%B2%D1%8B%D1%80%D1%83%D1%87%D0%BA%D0%B5%20%D1%82%D0%B5%D0%BA%D1%83%D1%89%D0%B5%D0%B3%D0%BE%3C/text%3E%0A%20%20%20%20%3Ctext%20x%3D%22695%22%20y%3D%22509%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%B8%20%D0%BF%D1%80%D0%B5%D0%B4%D1%8B%D0%B4%D1%83%D1%89%D0%B5%D0%B3%D0%BE%20%D0%BC%D0%B5%D1%81%D1%8F%D1%86%D0%B0%3C/text%3E%0A%20%20%20%20%3Cline%20x1%3D%22647%22%20y1%3D%22495%22%20x2%3D%22667%22%20y2%3D%22495%22%20stroke%3D%22black%22%20/%3E%0A%0A%20%20%20%20%3Crect%20x%3D%22696%22%20y%3D%22531%22%20width%3D%22203%22%20height%3D%2259%22%20rx%3D%2210%22%20stroke-width%3D%221.5%22%20style%3D%22fill%3A%23fff%3B%20stroke%3A%23ff4528%3B%22%20%20/%3E%0A%20%20%20%20%3Ctext%20x%3D%22710%22%20y%3D%22565%22%20font-size%3D%2214%22%20font-family%3D%22Arial%22%3E%D0%92%D1%8B%D1%80%D1%83%D1%87%D0%BA%D0%B0%20%D0%B2%20%D1%82%D0%B5%D0%BA%D1%83%D1%89%D0%B5%D0%BC%20%D0%BC%D0%B5%D1%81%D1%8F%D1%86%D0%B5%3C/text%3E%0A%20%20%20%20%3Cline%20x1%3D%22676%22%20y1%3D%22561%22%20x2%3D%22696%22%20y2%3D%22561%22%20stroke%3D%22black%22%20/%3E%0A%20%20%20%20%0A%3C/svg%3E)

# %% [markdown]
# 1. Нужно построить модель, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца.
# 2. В исследование нужно включить дополнительные данные финансового департамента о прибыльности клиента: какой доход каждый покупатель приносил компании за последние три месяца.
# 3. Используя данные модели и данные о прибыльности клиентов, нужно выделить сегменты покупателей и разработать для них персонализированные предложения.
#
# Руководство одобрило описание решения, и вам, как специалисту по DS, нужно его реализовать.
#
# # Описание данных
# Данные для работы находятся в нескольких таблицах.
# * `market_file.csv` - Таблица, которая содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
#   * `id` — номер покупателя в корпоративной базе данных.
#   * `Покупательская активность` — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
#   * `Тип сервиса` — уровень сервиса, например «премиум» и «стандарт».
#   * `Разрешить сообщать` — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
#   * `Маркет_актив_6_мес` — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
#   * `Маркет_актив_тек_мес` — количество маркетинговых коммуникаций в текущем месяце.
#   * `Длительность` — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
#   * `Акционные_покупки` — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
#   * `Популярная_категория` — самая популярная категория товаров у покупателя за последние 6 месяцев.
#   * `Средний_просмотр_категорий_за_визит` — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
#   * `Неоплаченные_продукты_штук_квартал` — общее число неоплаченных товаров в корзине за последние 3 месяца.
#   * `Ошибка_сервиса` — число сбоев, которые коснулись покупателя во время посещения сайта.
#   * `Страниц_за_визит` — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
#
# * `market_money.csv` - Таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
#   * `id` — номер покупателя в корпоративной базе данных.
#   * `Период` — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц'.
#   * `Выручка` — сумма выручки за период.
#
# * `market_time.csv` - Таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
#   * `id` — номер покупателя в корпоративной базе данных.
#   * `Период` — название периода, во время которого зафиксировано общее время.
#   * `минут` — значение времени, проведённого на сайте, в минутах.
#
# * `money.csv` - Таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
#   * `id` — номер покупателя в корпоративной базе данных.
#   * `Прибыль` — значение прибыли.
#
# # Инструкция по выполнению проекта
# Решать задачу вам нужно в два этапа:
# 1. Разработайте модель, которая предскажет вероятность снижения покупательской активности.
# 2. Выделите сегмент покупателей, проанализируйте его и предложите, как увеличить его покупательскую активность. Используйте данные моделирования, данные о прибыли покупателей и исходные данные (если понадобятся). По желанию вы можете проанализировать больше одного сегмента.
#
# Ниже несколько примеров сегментов, но вы также можете выделить свой:
#
# * Группа клиентов с максимальной долей покупок по акции и высокой вероятностью снижения покупательской активности.
# * Группа клиентов, которые покупают только технику, то есть товары с длинным жизненным циклом.
# * Группа клиентов, которые покупают товары из категории «Товары для себя» (новая категория, которую можно выделить на основе текущих) или «Товары для детей».
# * Группа клиентов с высокой вероятностью снижения покупательской активности и наиболее высокой прибыльностью.

# %% [markdown]
# ## Загрузка и изучение данных
# Импорт необходимых для выполнения проекта библиотек:

# %%
# !pip install scikit-learn==1.3.2 -q
# !pip install shap -q 
# !pip install phik -q

# %%
import pandas as pd              # Импорт библиотеки pandas
import matplotlib.pyplot as plt  # Импорт библиотеки для работы с графиками
import numpy as np               # Импорт библиотеки NumPy
from scipy import stats          # Импорт статистических функций из библиотеки SciPy
from phik import phik_matrix     # Импорт функции матрицы корреляции Фи
from phik.report import plot_correlation_matrix # Импорт функции отображения матрицы корреляции

from sklearn.model_selection import (train_test_split, # Импорт функции для разбивки датасета на выборки
                                     GridSearchCV) # Импорт инструмента автоматизированного поиска гиперпараметров

from sklearn.pipeline import Pipeline # Импорт Pipeline
from sklearn.preprocessing import (OneHotEncoder,  # Кодировщик OneHotEncoder
                                   OrdinalEncoder, # Кодировщик OrdinalEncoder
                                   StandardScaler, # Масштабирование: стандартизация
                                   MinMaxScaler,   # Масштабирование: нормализация
                                   LabelEncoder)   # Кодировщик LabelEncoder

from sklearn.impute import SimpleImputer # Импорт инструмента обработки пропусков

from sklearn.compose import ColumnTransformer # Импорт инструмента подготовки данных

# Импорт моделей машинного обучения:
from sklearn.linear_model import LogisticRegression # Логистическая регрессия
from sklearn.neighbors import KNeighborsClassifier  # Метод k-ближайших соседей
from sklearn.tree import DecisionTreeClassifier # Дерево решений
from sklearn.svm import SVC # Метод опорных векторов
from sklearn.dummy import DummyClassifier # Модель DummyClassifier

from sklearn.metrics import roc_auc_score # Импорт метрики ROC-AUC

import shap # Импорт инструмента оценки значимости признаков SHAP

# %% [markdown]
# Установка вспомогательных настроек, функций и констант:

# %%
# формат вывода float-чисел датафрейма:
pd.options.display.float_format = ("{:.2f}".format)

# настройка отображения графиков:
plt.rcParams["figure.figsize"] = (15,7) # размер графиков по умолчанию:
plt.rcParams.update({'axes.grid' : True, 'grid.alpha': 0.33, 'grid.linestyle': '--'}) # отображение сетки:

# установка цветовой палитры:
color_list = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', 
               '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# переменные для форматирования шрифта при выводе информации:
green, red, blue, pink, black, bold, end = '\33[92m', '\33[91m', '\33[36m', '\33[95m','\33[7m', '\33[1m','\33[0m'

# создание переменной псевдослучайности
RANDOM_STATE = 42

def dataset_info(df):
    """Функция для вывода общей информации о датасете"""
    print('• ' + '\33[4m' + 'Первые 10 строк датасета:' + end, f'[{df.dsc}]')
    display(df.head(10))
    print('• ' + '\33[4m' + 'Основная информация о датасете:' + end, f'[{df.dsc}]')
    df.info()

def stat_num(data_set, feature, rv=2, bins=50, d_type=False):
    """
    Функция отображения распределения числового признака.
    Для непрерывных величин строится диаграммы размаха и гистограммы распредления.
    Для дискретных величин стоится гистограмма.
    Выводится описательная информация.
    """
    param = data_set[feature]
    
    if d_type:
        pass
    else:
        d_type = param.dtype
    
    
    dsr = param.describe()
    iqr = dsr['75%'] - dsr['25%']
    if d_type == 'float':
        
        kde = stats.gaussian_kde(param)
        xx = np.linspace(dsr['min'], dsr['max'], bins)
        
        # конфигурация графиков:
        fig, axes = plt.subplots(nrows=1, ncols=2)
        # диаграмма размаха:
        param.plot(kind='box', ax=axes[0])
        axes[0].set_title('Разброс значений признака')
        axes[0].set_ylabel(feature_dsc[feature])
        
        # гистограмма:
        bns =  plt.hist(param, bins=bins, orientation='horizontal')
        scale = max(bns[0]) / max(kde(xx))
        # масштабированная линия плотности:
        plt.plot(0.9 * scale * kde(xx), xx);
        axes[1].set_title('Гистограмма распределения')
        axes[1].set_xlabel('Частота')
        axes[1].axhline(dsr['mean'], color='r', linestyle='--', label='Среднее значение')
        axes[1].axhline(dsr['50%'], color='r', linestyle=':', label='Медиана')
        axes[1].legend()
        plt.show()
        
        # описательная информация:
        print(f"Описательная информация для признака '{feature}':\n")
        print(bold + "Минимальное значение:" + end, 
         round(dsr['min'], 2), bold + "\t|\tМаксимальное значение:" + end, round(dsr['max'], 2))
        print(bold + "Среднее значение:" + end, f"{round(dsr['mean'], rv)}")
        print(bold + "Медиана:" + end, round(dsr['50%'], 2))
        print(bold + "Межквартильный размах IQR:" + end, round(iqr, rv))
        print(bold + "Границы нормальных значений:" + end, 
          f"от {round(max([dsr['25%'] - 1.5*iqr, dsr['min']]), rv)} до",
          f"{round(min([dsr['75%'] + 1.5*iqr, dsr['max']]), rv)}")
    
    elif d_type == 'int':
        data = param.value_counts().sort_index()
        cmap = plt.cm.winter
        colors = cmap(np.linspace(0,1,data.shape[0]))
        plt.bar(data.index, data.values, color=colors, width=0.985, edgecolor='w')
        plt.title(f"Распределение значений признака '{feature}'")
        plt.xlabel(feature_dsc[feature])
        plt.ylabel("Частота")
        plt.xticks(data.index)
        plt.show()
        
        # описательная информация:
        print(f"Описательная информация для признака '{feature}':\n")
        print(bold + "Минимальное значение:" + end, 
         int(dsr['min']), bold + "\t|\tМаксимальное значение:" + end, int(dsr['max']))
        print(bold + "Среднее значение:" + end, f"{round(dsr['mean'], rv)}")
        print(bold + "Медиана:" + end, int(dsr['50%']))
        print(bold + "Мода:" + end, param.mode()[0])
        
    else:
        pass

def stat_cat(data_set, param, labels=False):
    """
    Функция анализа распределения категориального признака
    """
    data_set_plt = data_set[param].value_counts().sort_values()
    
    if labels:
        pass
    else:
        labels = data_set[param].value_counts().sort_values().index

    # конфигурация графиков:
    fig, axes = plt.subplots(nrows=1, ncols=2)
    
    # столбчатый график:
    data_set_plt.plot(kind='barh', color=color_list, ax=axes[0])
    axes[0].set_title('Абсолютное распределение')
    axes[0].set_ylabel(feature_dsc[param])
    axes[0].set_xlabel('Частота')
    axes[0].set_yticklabels(labels)
    
    # круговая диаграмма:
    data_set_plt.plot(kind='pie', autopct='%1.1f%%', ax=axes[1], labels=labels)
    axes[1].set_title('Относительное распределение')
    axes[1].yaxis.set_visible(False)
    
    plt.suptitle('Распределение значений признаков')
    plt.show()
    
    # описательная информация:
    print(f"Значения признака '{param}' распределены следующим образом:")
    print(bold + "- Всего значений:" + end, len(data_set))
    print(bold + "- Уникальных значений:" + end, len(data_set[param].unique()), data_set[param].unique())
    print("В том числе:")
    for el in data_set[param].unique():
        print(bold + f"- {el}:" + end, len(data_set[data_set[param] == el]), 
              f"({round(100*len(data_set[data_set[param] == el])/len(data_set), 2)}%)")

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ### Загрузка данных
# Загрузим данные в датафреймы:

# %%
market_file  = pd.read_csv('/datasets/market_file.csv')
market_money = pd.read_csv('/datasets/market_money.csv')
market_time  = pd.read_csv('/datasets/market_time.csv')
money        = pd.read_csv('/datasets/money.csv', sep=";")

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ### Изучение данных
# Для удобства и наглядности информации зададим имеющимся датасетам свойства с именами:

# %%
market_file.dsc  = 'market_file'
market_money.dsc = 'market_money'
market_time.dsc  = 'market_time'
money.dsc        = 'money'

# %% [markdown]
# Выведем общую информацию об имеющихся датасетах:

# %%
for d in [market_file, market_money, market_time, money]:
    dataset_info(d)
    print('\n* * *\n')
# Out:
# • Первые 10 строк датасета: [market_file]
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
# 5  215353                 Снизилась   стандартт                 да
# 6  215354                 Снизилась   стандартт                 да
# 7  215355                 Снизилась   стандартт                нет
# 8  215356                 Снизилась   стандартт                 да
# 9  215357                 Снизилась   стандартт                 да
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                3.40                     5           121               0.00
# ...

# %% [markdown]
# **Выводы**:
# * Датасет `market_file`:
#   * Состоит из 13 столбцов и 1300 строк.
#   * Наименования столбцов соответствуют описанию.
#   * Не содержит пропусков.
#
# * Датасет `market_money`:
#   * Состоит из 3 столбцов и 3900 строк.
#   * Наименования столбцов соответствуют описанию.
#   * Не содержит пропусков.
#   * По содержанию состоит из записей о выручке за 3 периода - отсюда и количество строк втрое больше, чем у `market_file`
#
# * Датасет `market_time`:
#   * Состоит из 3 столбцов и 2600 строк.
#   * Наименования столбцов соответствуют описанию.
#   * Не содержит пропусков.
#   * По содержанию состоит из записей о времени покупателя, проведенном на сайте за "текущий_месяц" и "предыдцщий_месяц"  - отсюда и количество строк вдвое больше, чем у `market_file`
#
# * Датасет `money`:
#   * Состоит из 2 столбцов и 1300 строк.
#   * Наименования столбцов соответствуют описанию.
#   * Не содержит пропусков.
#
# * Имеющиеся данные соответствуют описанию и структуре, заявленным заказчиком.
# * Значения ячеек выглядят реалистично.
# * Значения ячеек выглядят уникально.
# * Названия всех столбцов, кроме `id`, указаны на кириллице.

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ## Предобработка данных
# ### Переименование столбцов
# Отобразим заголовки столбцов для наших данных:

# %%
print("Заголовки датасета:")
for d in [market_file, market_money, market_time, money]:
    print('• '+ bold + d.dsc + end, d.columns.to_list())
    print()
# Out:
# Заголовки датасета:
# • market_file ['id', 'Покупательская активность', 'Тип сервиса', 'Разрешить сообщать', 'Маркет_актив_6_мес', 'Маркет_актив_тек_мес', 'Длительность', 'Акционные_покупки', 'Популярная_категория', 'Средний_просмотр_категорий_за_визит', 'Неоплаченные_продукты_штук_квартал', 'Ошибка_сервиса', 'Страниц_за_визит']
#
# • market_money ['id', 'Период', 'Выручка']
#
# • market_time ['id', 'Период', 'минут']
#
# • money ['id', 'Прибыль']

# %% [markdown]
# Как видно, заголовки данных, за исключением `id`, указаны на кириллице.
#
# Согласно условиям исследования, названия столбцов можно оставить кириллическими.
#
# Ради единообразия преобразуем пробелы в заголовках датасета `market_file` в нижние подчеркивания, а для датасета `market_time` изменим регистр столбца `минут`:

# %%
market_file.columns = market_file.columns.str.replace(' ', '_')
market_time.rename(columns={'минут':'Минут'}, inplace=True)

# %% [markdown]
# **Выводы**:
# * Названия столбцов, за исключением `id`, указаны на кириллице.
# * Согласно условиям исследования, названия оставлены в таком же виде.
# * Пробелы в заголовках заменены на нижние подчеркивания

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ### Обработка пропусков
# На этапе первичного ознакомления с данными пропусков замечено не было. Убедимся в этом еще раз:

# %%
for d in [market_file, market_money, market_time, money]:
    print(f'- Количество пропусков в датасете {d.dsc}: {d.isna().sum().sum()}')
# Out:
# - Количество пропусков в датасете market_file: 0
# - Количество пропусков в датасете market_money: 0
# - Количество пропусков в датасете market_time: 0
# - Количество пропусков в датасете money: 0

# %% [markdown]
# **Вывод**: убедились, что в имеющихся датасетах действительно отсутствуют пропуски.

# %% [markdown]
# ### Изменение типов данных
# Для имеющихся датасетов отобразим 1 произвольную строку с данными, а также строку с указанием типов данных:

# %%
for d in [market_file, market_money, market_time, money]:
    display(f'Датасет {d.dsc}:')
    display(pd.concat([d.sample(), pd.DataFrame(d.dtypes, columns=['dtypes']).transpose()]))
# Out:
# 'Датасет market_file:'
#             id Покупательская_активность Тип_сервиса Разрешить_сообщать  \
# 351     215699                 Снизилась    стандарт                нет
# dtypes   int64                    object      object             object
#
#        Маркет_актив_6_мес Маркет_актив_тек_мес Длительность Акционные_покупки  \
# 351                  4.10                    3          811              0.93
# dtypes            float64                int64        int64           float64
#
#          Популярная_категория Средний_просмотр_категорий_за_визит  \
# 351     Косметика и аксесуары                                   4
# dtypes                 object                               int64
#
#        Неоплаченные_продукты_штук_квартал Ошибка_сервиса Страниц_за_визит
# 351                                     1              5                8
# dtypes                              int64          int64            int64
# 'Датасет market_money:'
# ...

# %% [markdown]
# В целом, все признаки имеют подходящий тип данных, кроме столбца `Прибыль` датасета `money`, значения которого представлены типом `object`.
# Преобразуем значения признака в тип `float`:

# %%
# изменение типа данных:
money['Прибыль'] = money['Прибыль'].str.replace(',', '.').astype(float)

# вывод значений:
pd.concat([money.sample(), pd.DataFrame(money.dtypes, columns=['dtypes']).transpose()])
# Out:
#             id  Прибыль
# 617     215965     3.72
# dtypes   int64  float64

# %% [markdown]
# **Выводы**:
# * Для столбца `Прибыль` датасета `money` изменили тип данных на `float`.
# * Остальные признаки не требовали изменения типа данных.

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ### Обработка дубликатов
# #### Обработка неявных дубликатов
# Перед тем как искать полные дубликаты, проверим насколько уникальны значения в строковых признаках.
#
# Отобразим уникальные значения таких признаков:

# %%
for d in [market_file, market_money, market_time]:
    print(bold + d.dsc + end + ':')
    for c in d.columns:
        if d[c].dtype == 'object':
            print(f'- {c}: {d[c].unique()}')
    print()
# Out:
# market_file:
# - Покупательская_активность: ['Снизилась' 'Прежний уровень']
# - Тип_сервиса: ['премиум' 'стандартт' 'стандарт']
# - Разрешить_сообщать: ['да' 'нет']
# - Популярная_категория: ['Товары для детей' 'Домашний текстиль' 'Косметика и аксесуары'
#  'Техника для красоты и здоровья' 'Кухонная посуда'
#  'Мелкая бытовая техника и электроника']
#
# market_money:
# - Период: ['препредыдущий_месяц' 'текущий_месяц' 'предыдущий_месяц']
#
# market_time:
# - Период: ['текущий_месяц' 'предыдцщий_месяц']

# %% [markdown]
# Выявлено одно дублирующее значение 'стандартт' (признак `Тип_сервиса`, датасет `market_file`), а также одно значение указанное с орфографической ошибкой 'предыдцщий_месяц' (признак `Период`, датасет `market_money`).
# Исправим:
#
# Текущее значение|Новое значение
# -|-
# стандартт|стандарт
# предыдцщий_месяц|предыдущий_месяц

# %%
# замена значений:
market_file['Тип_сервиса'] = market_file['Тип_сервиса'].str.replace('стандартт', 'стандарт')
market_time['Период'] = market_time['Период'].str.replace('предыдцщий_месяц', 'предыдущий_месяц')

# %% [markdown]
# Еще раз проверим значения:

# %%
for d in [market_file, market_money, market_time]:
    print(bold + d.dsc + end + ':')
    for c in d.columns:
        if d[c].dtype == 'object':
            print(f'- {c}: {d[c].unique()}')
    print()
# Out:
# market_file:
# - Покупательская_активность: ['Снизилась' 'Прежний уровень']
# - Тип_сервиса: ['премиум' 'стандарт']
# - Разрешить_сообщать: ['да' 'нет']
# - Популярная_категория: ['Товары для детей' 'Домашний текстиль' 'Косметика и аксесуары'
#  'Техника для красоты и здоровья' 'Кухонная посуда'
#  'Мелкая бытовая техника и электроника']
#
# market_money:
# - Период: ['препредыдущий_месяц' 'текущий_месяц' 'предыдущий_месяц']
#
# market_time:
# - Период: ['текущий_месяц' 'предыдущий_месяц']

# %% [markdown]
# **Вывод**: устранены неявные дубликаты значений среди признаков, а также исправлены орфографические ошибки.

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### Обработка явных дубликатов
# Теперь проверим, есть ли явные дубликаты в данных:

# %%
print('Количество дублирующихся строк:')
for df in [market_file, market_money, market_time, money]:
    print(f'- {df.dsc}: {df.duplicated().sum()}')
# Out:
# Количество дублирующихся строк:
# - market_file: 0
# - market_money: 0
# - market_time: 0
# - money: 0

# %% [markdown]
# Полные дубликаты строк в имеющихся данных отсутствуют.
#
# Также проверим - есть ли дубликаты среди значений `id` датасета `market_file`:

# %%
market_file.duplicated(subset=['id']).sum()
# Out:
# 0

# %% [markdown]
# И удостоверимся, что во всех датасетах идентичный набор значений `id`:

# %%
(set(market_file['id'].unique()) == set(market_money['id'].unique()) == 
 set(market_time['id'].unique()) == set(money['id'].unique()))
# Out:
# True

# %% [markdown]
# **Выводы**:
# * Полные дубликаты строк в имеющихся данных отсутствуют.
# * Значения столбца `id` датасета `market_file` уникальны - это значит, что эти значения могут быть использованы в качестве ключа при объединении датасетов.
# * Все имеющиеся датасеты содержат идентичный набор значений `id`.

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ## Исследовательский анализ данных
#
# Сформируем списки содержащие количественные и категориальные данные:

# %%
num_col_names = []
cat_col_names = []

for d in [market_file, market_money, market_time, money]:
    num_col_names.extend(d.select_dtypes(exclude='object').columns.drop('id').tolist())
    cat_col_names.extend(d.select_dtypes(include='object').columns.tolist())

print(bold + "Количественные признаки:" + end, num_col_names, '\n')
print(bold + "Категориальные признаки:" + end, cat_col_names)
# Out:
# Количественные признаки: ['Маркет_актив_6_мес', 'Маркет_актив_тек_мес', 'Длительность', 'Акционные_покупки', 'Средний_просмотр_категорий_за_визит', 'Неоплаченные_продукты_штук_квартал', 'Ошибка_сервиса', 'Страниц_за_визит', 'Выручка', 'Минут', 'Прибыль']
#
# Категориальные признаки: ['Покупательская_активность', 'Тип_сервиса', 'Разрешить_сообщать', 'Популярная_категория', 'Период', 'Период']

# %% [markdown]
# Для более наглядного представления полученных результатов я сформирую словарь с описанием признаков.

# %%
feature_dsc = {'Маркет_актив_6_мес':'Количество коммуникаций с покупателем',
               'Маркет_актив_тек_мес':'Количество коммуникаций с покупателем',
               'Длительность':'Количество дней после регистрации',
               'Акционные_покупки':'Доля акционных покупок',
               'Средний_просмотр_категорий_за_визит':'Среднее количество просмотренных категорий за визит',
               'Неоплаченные_продукты_штук_квартал':'Число неоплаченных товаров в корзине',
               'Ошибка_сервиса':'Число сбоев, которые коснулись покупателя',
               'Страниц_за_визит':'Среднее количество страниц, которые просмотрел покупатель за один визит',
               'Выручка':'Сумма выручки',
               'Минут':'Количество минут проведенных на сайте',
               'Прибыль':'Прибыль от покупателя',
               'Покупательская_активность':'Тип активности',
               'Тип_сервиса':'Тип сервиса',
               'Разрешить_сообщать':'Согласие на доп. рассылку',
               'Популярная_категория':'Самая популярная категория товаров у покупателя',
               'Период':'Период фиксации выручки',
               'Период':'Период фиксации времени посещения'
              }

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ### Анализ количественных признаков
# #### Признак `Маркет_актив_6_мес`
# Датасет `market_file`, признак `Маркет_актив_6_мес`.
#
# Признак отображает среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев.
# Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.

# %%
stat_num(market_file, 'Маркет_актив_6_мес')
# Out:
# Описательная информация для признака 'Маркет_актив_6_мес':
#
# Минимальное значение: 0.9 	|	Максимальное значение: 6.6
# Среднее значение: 4.25
# Медиана: 4.2
# Межквартильный размах IQR: 1.2
# Границы нормальных значений: от 1.9 до 6.6

# %% [markdown]
# **Выводы**:
# * Для признака `Маркет_актив_6_мес` не наблюдается явно аномальных значений данных
# * Присутствуют данные выходящие за нормальных значений (ниже 2), но эти данные не являются ошибочными.
# * Данные распределены достаточно равномерно, без заметного перекоса

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### Признак "Маркет_актив_тек_мес"
# Датасет `market_file`, признак `Маркет_актив_тек_мес`.
#
# Признак отображает количество маркетинговых коммуникаций в текущем месяце.

# %%
stat_num(market_file, 'Маркет_актив_тек_мес')
# Out:
# Описательная информация для признака 'Маркет_актив_тек_мес':
#
# Минимальное значение: 3 	|	Максимальное значение: 5
# Среднее значение: 4.01
# Медиана: 4
# Мода: 4

# %% [markdown]
# **Выводы**:
# * По сравнению с аналогичным признаком `Маркет_актив_6_мес` - данный признак показывает низкую вариативность данных. Мода равна 4, а два других значения - соседние 3 и 5.
# * Стоить отметить низкую информативность признака и учесть это при моделировании и анализе признаков.

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### Признак "Длительность"
# Датасет `market_file`, признак `Длительность`.
#
# Признак отображает сколько дней прошло с момента регистрации покупателя на сайте.

# %%
stat_num(market_file, 'Длительность', d_type='float')
# Out:
# Описательная информация для признака 'Длительность':
#
# Минимальное значение: 110.0 	|	Максимальное значение: 1079.0
# Среднее значение: 601.9
# Медиана: 606.0
# Межквартильный размах IQR: 400.5
# Границы нормальных значений: от 110.0 до 1079.0

# %% [markdown]
# **Выводы**:
# * Для признака `Длительность` не наблюдается явно аномальных значений данных
# * Отсутствуют данные выходящие за нормальных значений.
# * Данные распределены достаточно равномерно, без заметного перекоса

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### Признак "Акционные_покупки"
# Датасет `market_file`, признак `Акционные_покупки`.
#
# Признак отображает среднемесячную долю покупок по акции от общего числа покупок за последние 6 месяцев.

# %%
stat_num(market_file, 'Акционные_покупки')
# Out:
# Описательная информация для признака 'Акционные_покупки':
#
# Минимальное значение: 0.0 	|	Максимальное значение: 0.99
# Среднее значение: 0.32
# Медиана: 0.24
# Межквартильный размах IQR: 0.13
# Границы нормальных значений: от 0.0 до 0.49

# %% [markdown]
# **Выводы**:
# * Для признака `Акционные_покупки` не наблюдается явно аномальных значений данных
# * Присутствуют данные выходящие за нормальных значений (от 0.6 и выше), но эти данные не являются ошибочными.
# * Заметно два центра концертрации значений - первый у медианы, равной 0.24, второй у значений близким к 1.0

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### Признак "Средний_просмотр_категорий_за_визит"
# Датасет `market_file`, признак `Средний_просмотр_категорий_за_визит`.
#
# Признак отображает сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.

# %%
stat_num(market_file, 'Средний_просмотр_категорий_за_визит')
# Out:
# Описательная информация для признака 'Средний_просмотр_категорий_за_визит':
#
# Минимальное значение: 1 	|	Максимальное значение: 6
# Среднее значение: 3.27
# Медиана: 3
# Мода: 3

# %% [markdown]
# **Выводы**:
# * Для признака `Средний_просмотр_категорий_за_визит` не наблюдается явно аномальных значений данных
# * Отсутствуют данные выходящие за нормальных значений.
# * Данные распределены достаточно равномерно, без заметного перекоса

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### Признак "Неоплаченные_продукты_штук_квартал"
# Датасет `market_file`, признак `Неоплаченные_продукты_штук_квартал`.
#
# Признак отображает общее число неоплаченных товаров в корзине за последние 3 месяца.

# %%
stat_num(market_file, 'Неоплаченные_продукты_штук_квартал')
# Out:
# Описательная информация для признака 'Неоплаченные_продукты_штук_квартал':
#
# Минимальное значение: 0 	|	Максимальное значение: 10
# Среднее значение: 2.84
# Медиана: 3
# Мода: 1

# %% [markdown]
# **Выводы**:
# * Для признака `Неоплаченные_продукты_штук_квартал` не наблюдается явно аномальных значений данных.
# * При распределении данных от 0 до 10, основная концентрация значений сосредоточена вблизи медианы равной 3.

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### Признак "Ошибка_сервиса"
# Датасет `market_file`, признак `Ошибка_сервиса`.
#
# Признак отображает число сбоев, которые коснулись покупателя во время посещения сайта.

# %%
stat_num(market_file, 'Ошибка_сервиса')
# Out:
# Описательная информация для признака 'Ошибка_сервиса':
#
# Минимальное значение: 0 	|	Максимальное значение: 9
# Среднее значение: 4.19
# Медиана: 4
# Мода: 4

# %% [markdown]
# **Выводы**:
# * Для признака `Ошибка_сервиса` не наблюдается явно аномальных значений данных
# * Данные распределены достаточно равномерно, без заметного перекоса

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### Признак "Страниц_за_визит"
# Датасет `market_file`, признак `Страниц_за_визит`.
#
# Признак отображает среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.

# %%
stat_num(market_file, 'Страниц_за_визит')
# Out:
# Описательная информация для признака 'Страниц_за_визит':
#
# Минимальное значение: 1 	|	Максимальное значение: 20
# Среднее значение: 8.18
# Медиана: 8
# Мода: 6

# %% [markdown]
# **Выводы**:
# * Для признака `Страниц_за_визит` не наблюдается явно аномальных значений данных
# * Данные распределены достаточно равномерно, без заметного перекоса

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### Признак "Выручка"
# Датасет `market_money`, признак `Выручка`.
#
# Признак отображает сумму выручки, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.

# %%
stat_num(market_money, 'Выручка')
# Out:
# Описательная информация для признака 'Выручка':
#
# Минимальное значение: 0.0 	|	Максимальное значение: 106862.2
# Среднее значение: 5025.7
# Медиана: 4957.5
# Межквартильный размах IQR: 772.85
# Границы нормальных значений: от 3430.87 до 6522.28

# %% [markdown]
# Среди всех значений признака "Выручка", которые отображены на диаграмме размаха, обращает на себя наличие выброса далеко за пределами нормальных значений.
#
# Отобразим топ-10 значений признака "Выручка" в убывающем порядке:

# %%
(pd.DataFrame(market_money['Выручка']).sort_values(by='Выручка', ascending=False).head(10)
   .style.format({'Выручка': '{:.1f}'}).highlight_max(axis=0))
# Out:
# <style  type="text/css" >
# #T_4cb99_row0_col0{
#             background-color:  yellow;
#         }</style><table id="T_4cb99_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Выручка</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4cb99_level0_row0" class="row_heading level0 row0" >98</th>
#                         <td id="T_4cb99_row0_col0" class="data row0 col0" >106862.2</td>
#             </tr>
#             <tr>
#                         <th id="T_4cb99_level0_row1" class="row_heading level0 row1" >435</th>
#                         <td id="T_4cb99_row1_col0" class="data row1 col0" >7799.4</td>
#             </tr>
#             <tr>
#                         <th id="T_4cb99_level0_row2" class="row_heading level0 row2" >262</th>
#                         <td id="T_4cb99_row2_col0" class="data row2 col0" >7605.3</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# Среди топ-списка по выручке, значение `106862.2` явно выделяется.
# Проверим данную запись:

# %%
market_money[market_money.index == 98]
# Out:
#         id         Период   Выручка
# 98  215380  текущий_месяц 106862.20

# %% [markdown]
# Также проверим информацию для данного `id` в других таблицах:

# %%
for d in [market_file, market_money, market_time, money]:
    print(d.dsc + ':')
    display(d[d['id'] == 215380])
# Out:
# market_file:
#         id Покупательская_активность Тип_сервиса Разрешить_сообщать  \
# 32  215380                 Снизилась     премиум                нет
#
#     Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 32                1.70                     4           637               0.94
#
#               Популярная_категория  Средний_просмотр_категорий_за_визит  \
# 32  Техника для красоты и здоровья                                    3
#
#     Неоплаченные_продукты_штук_квартал  Ошибка_сервиса  Страниц_за_визит
# 32                                   2               4                 7
# market_money:
#         id               Период   Выручка
# 96  215380  препредыдущий_месяц   5051.00
# 97  215380     предыдущий_месяц   6077.00
# 98  215380        текущий_месяц 106862.20
# market_time:
#         id            Период  Минут
# 64  215380  предыдущий_месяц     12
# 65  215380     текущий_месяц     14
# money:
#         id  Прибыль
# ...

# %% [markdown]
# * Само по себе значение `106862.20` для признака **Выручка** вполне может быть реальным (`id=215380` - премиум клиент с популярной категорией покупок "Техника для красоты и здоровья"), хоть и явно выделяется среди остальных значений.
# * Обращает внимание, что **Выручка** покупателя по месяцам в хронологическом порядке имеет значения:
#   * 5051.00
#   * 6077.00
#   * 106862.20
# При этом, **Покупательская_активность** данного покупателя, как показывает информация из датасета `market_file`, - **снизилась**.<br>
# <font color='red'>*</font> *Здесь следует сделать оговорку, что в условиях четко не обозначено как рассчитывается "активность" покупателей*.
# * Вышеизложенная информация выявляет противоречие - наиболее вероятно, что в данных содержится ошибка. Причем, помимо очевидной ошибки в показателях **Выручка**, нет уверенности в корректности остальных данных для данного `id`.
# * С целью улучшения качества данных принимаю решение удалить записи с данным `id` из датасетов.

# %%
# удаление id с аномальными значениями выручки из датасетов:

# установка порога аномальных значений:
anomaly_threshold = 20000

# получение списка id с аномальными значеними:
anomaly_id = market_money.query('Выручка > @anomaly_threshold')['id'].to_list()
display(f"id клиентов превышающих порог выручки ({anomaly_threshold}): {anomaly_id}")

# удаление аномальных id из датасетов:
market_file.drop(market_file[market_file['id'].isin(anomaly_id)].index.to_list(), inplace=True)
market_money.drop(market_money[market_money['id'].isin(anomaly_id)].index.to_list(), inplace=True)
market_time.drop(market_time[market_time['id'].isin(anomaly_id)].index.to_list(), inplace=True)
money.drop(money[money['id'].isin(anomaly_id)].index.to_list(), inplace=True)
# Out:
# 'id клиентов превышающих порог выручки (20000): [215380]'

# %% [markdown]
# Еще раз отобразим распределение данных для признака `Выручка`:

# %%
stat_num(market_money, 'Выручка')
# Out:
# Описательная информация для признака 'Выручка':
#
# Минимальное значение: 0.0 	|	Максимальное значение: 7799.4
# Среднее значение: 4999.29
# Медиана: 4956.0
# Межквартильный размах IQR: 773.0
# Границы нормальных значений: от 3430.5 до 6522.5

# %% [markdown]
# Теперь в данных заметны значения с нулевой выручкой:
#
# Но, в отличие от предыдущего случая, эти значения не выглядят аномальными или ошибочными.

# %% [markdown]
# **Выводы**:
# * Для признака `Выручка` было удалено одно аномальное значение `106862.2`. Также из датасетов был удален покупатель с `id`=215380, для которого зафиксировалось это аномальное значение. Других аномальных значений не выявлено.
# * Присутствуют данные выходящие за границы нормальных значений - выше и ниже границ, а также - отдельно значения равные 0. Значения равные 0 не являются ошибочными, отсутствие значений в диапазоне от 0 до 2758.7 (вторая минимальная выручка после 0) означает, что для этих значений просто нет доступных товаров.
# * Данные распределены достаточно равномерно, без заметного перекоса

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### Признак "минут"
# Датасет `market_time`, признак `Минут`.
#
# Признак отображает время (в минутах), которое покупатель провёл на сайте в течение периода.

# %%
stat_num(market_time, 'Минут')
# Out:
# Описательная информация для признака 'Минут':
#
# Минимальное значение: 4 	|	Максимальное значение: 23
# Среднее значение: 13.34
# Медиана: 13
# Мода: 14

# %% [markdown]
# **Выводы**:
# * Для признака `Минут` не наблюдается явно аномальных значений данных
# * Данные распределены достаточно равномерно, без заметного перекоса

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### Признак "Прибыль"
# Датасет `money`, признак `Прибыль`.
#
# Признак отображает прибыль, которую получает магазин от продаж каждому покупателю за последние 3 месяца.

# %%
stat_num(money, 'Прибыль')
# Out:
# Описательная информация для признака 'Прибыль':
#
# Минимальное значение: 0.86 	|	Максимальное значение: 7.43
# Среднее значение: 4.0
# Медиана: 4.05
# Межквартильный размах IQR: 1.37
# Границы нормальных значений: от 1.24 до 6.72

# %% [markdown]
# **Выводы**:
# * Для признака `Прибыль` не наблюдается явно аномальных значений данных
# * Присутствуют данные выходящие за нормальных значений - выше и ниже границы нормальных значений, но эти данные не являются ошибочными.
# * Данные распределены достаточно равномерно, без заметного перекоса

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ### Анализ категориальных признаков
# #### Признак "Покупательская_активность" (целевой признак)
# Датасет `market_file`, признак `Покупательская активность`.
#
# Признак отображает класс покупательской активности: «снизилась» или «прежний уровень»

# %%
stat_cat(market_file, 'Покупательская_активность')
# Out:
# Значения признака 'Покупательская_активность' распределены следующим образом:
# - Всего значений: 1299
# - Уникальных значений: 2 ['Снизилась' 'Прежний уровень']
# В том числе:
# - Снизилась: 497 (38.26%)
# - Прежний уровень: 802 (61.74%)

# %% [markdown]
# **Выводы:**
# * Целевой признак `Покупательская_активность` представлен 2 уникальными значениями - 'Снизилась' и 'Прежний уровень'
# * Признаки распределены с дисбалансом 62% / 38 %
# * Наличие дисбаланса может повлиять на точность предсказания модели - необходимо это учесть при обучении моделей.
# * Положительный момент в том, что у основной массы клиентов сохраняется покупательская активность.

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### Признак "Тип_сервиса"
# Датасет `market_file`, признак `Тип сервиса`.
#
# Признак отображает уровень сервиса покупателя, например «премиум» и «стандарт».

# %%
stat_cat(market_file, 'Тип_сервиса')
# Out:
# Значения признака 'Тип_сервиса' распределены следующим образом:
# - Всего значений: 1299
# - Уникальных значений: 2 ['премиум' 'стандарт']
# В том числе:
# - премиум: 375 (28.87%)
# - стандарт: 924 (71.13%)

# %% [markdown]
# **Выводы:**
# * Признак `Тип_сервиса` представлен 2 уникальными значениями - 'премиум' и 'стандарт'
# * Признаки распределены с дисбалансом 71% / 29 % - основная масса покупателей 'стандарт'-сервиса

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### Признак "Разрешить_сообщать"
# Датасет `market_file`, признак `Разрешить сообщать`.
#
# Признак отображает информацию о том, можно ли присылать покупателю дополнительные предложения о товаре

# %%
stat_cat(market_file, 'Разрешить_сообщать')
# Out:
# Значения признака 'Разрешить_сообщать' распределены следующим образом:
# - Всего значений: 1299
# - Уникальных значений: 2 ['да' 'нет']
# В том числе:
# - да: 962 (74.06%)
# - нет: 337 (25.94%)

# %% [markdown]
# **Выводы:**
# * Признак `Разрешить_сообщать` представлен 2 уникальными значениями - 'да' и 'нет'
# * Признаки распределены с дисбалансом 74% / 26 % - основная масса покупателей согласна на дополнительную рассылку

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### Признак "Популярная_категория"
# Датасет `market_file`, признак `Популярная_категория`.
#
# Признак отображает самую популярную категорию товаров у покупателя за последние 6 месяцев.

# %%
stat_cat(market_file, 'Популярная_категория', 
          labels=['Кухонная\nпосуда', 'Мелкая бытовая\nтехника и\nэлектроника',
                  'Техника\nдля красоты\nи здоровья', 'Косметика\nи аксесуары',
                  'Домашний\nтекстиль', 'Товары\nдля детей']
         )
# Out:
# Значения признака 'Популярная_категория' распределены следующим образом:
# - Всего значений: 1299
# - Уникальных значений: 6 ['Товары для детей' 'Домашний текстиль' 'Косметика и аксесуары'
#  'Техника для красоты и здоровья' 'Кухонная посуда'
#  'Мелкая бытовая техника и электроника']
# В том числе:
# - Товары для детей: 330 (25.4%)
# - Домашний текстиль: 251 (19.32%)
# - Косметика и аксесуары: 223 (17.17%)
# - Техника для красоты и здоровья: 183 (14.09%)
# - Кухонная посуда: 138 (10.62%)
# - Мелкая бытовая техника и электроника: 174 (13.39%)

# %% [markdown]
# **Выводы:**
# * Признак `Популярная_категория` представлен 6 уникальными значениями:
#   * 'Товары для детей'
#   * 'Домашний текстиль'
#   * 'Косметика и аксесуары'
#   * 'Техника для красоты и здоровья'
#   * 'Кухонная посуда'
#   * 'Мелкая бытовая техника и электроника'
# * Признаки распределены с постепенным убыванием от самой популярной категории 'Товары для детей' до наименее популярной - 'Кухонная посуда'

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### Признак "Период" (market_money)
# Датасет `market_money`, признак `Период`.
#
# Признак отображает название периода, во время которого зафиксирована выручка, которую получает магазин с покупателя.

# %%
stat_cat(market_money, 'Период', labels=['текущий\nмесяц', 'предыдущий\nмесяц',
                  'препредыдущий\nмесяц'])
# Out:
# Значения признака 'Период' распределены следующим образом:
# - Всего значений: 3897
# - Уникальных значений: 3 ['препредыдущий_месяц' 'текущий_месяц' 'предыдущий_месяц']
# В том числе:
# - препредыдущий_месяц: 1299 (33.33%)
# - текущий_месяц: 1299 (33.33%)
# - предыдущий_месяц: 1299 (33.33%)

# %% [markdown]
# **Выводы:**
# * Признак `Период` представлен 3 уникальными значениями - 'препредыдущий_месяц', 'текущий_месяц' и 'предыдущий_месяц'
# * Признаки распределены равномерно между указанными значениями.

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# #### Признак "Период" (market_time)
# Датасет `market_time`, признак `Период`.
#
# Признак отображает название периода, в котором зафиксировано общее время (в минутах), которое покупатель провёл на сайте

# %%
stat_cat(market_time, 'Период')
# Out:
# Значения признака 'Период' распределены следующим образом:
# - Всего значений: 2598
# - Уникальных значений: 2 ['текущий_месяц' 'предыдущий_месяц']
# В том числе:
# - текущий_месяц: 1299 (50.0%)
# - предыдущий_месяц: 1299 (50.0%)

# %% [markdown]
# **Выводы:**
# * Признак `Период` представлен 2 уникальными значениями - 'текущий_месяц' и 'предыдущий_месяц'
# * Признаки распределены равномерно между указанными значениями.

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ### Отбор клиентов с покупательской активностью не менее трёх месяцев
#
# Необходимо отобрать клиентов с покупательской активностью **не менее трёх месяцев**, то есть таких, которые что-либо покупали в этот период.
#
# Это можно осуществить на основании информации из датасета `market_money`, где представлены данные о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.

# %%
market_money.head(9)
# Out:
#        id               Период  Выручка
# 0  215348  препредыдущий_месяц     0.00
# 1  215348        текущий_месяц  3293.10
# 2  215348     предыдущий_месяц     0.00
# 3  215349  препредыдущий_месяц  4472.00
# 4  215349        текущий_месяц  4971.60
# 5  215349     предыдущий_месяц  5216.00
# 6  215350  препредыдущий_месяц  4826.00
# 7  215350        текущий_месяц  5058.40
# 8  215350     предыдущий_месяц  5457.50

# %% [markdown]
# Датасет содержит информацию о выручке за последние 3 месяца.
#
# Преобразуем данные, аггрегировав для каждого покупателя суммарную выручку:

# %%
money_check = market_money.pivot_table(index='id', values='Выручка', aggfunc='sum')
money_check.head(3)
# Out:
#         Выручка
# id
# 215348  3293.10
# 215349 14659.60
# 215350 15341.90

# %% [markdown]
# Проверим предположение, что для каждого `id` суммарная выручка больше 0:

# %%
all(money_check['Выручка'] > 0)
# Out:
# True

# %% [markdown]
# Выражение истинно.
#
# **Вывод**:
# * Все покупатели, `id` которых содержатся в датасете `market_money` совершали хотя бы одну покупку за последние 3 месяца.
# * Поскольку ранее в [пунтке 2.4.1](#Обработка-неявных-дубликатов) мы проверили, что все имеющиеся датасеты содержат идентичный набор `id`, можно заключить, что все представленные в имеющихся данных покупатели совершали какую-либо покупку за последние 3 месяца.

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ## Объединение таблиц
# По условиям проекта, данные представлены в виде четырех датасетов:
# * `market_file`
# * `market_money`
# * `market_time`
# * `money`
#
# Датасеты содержат информацию о разных признаках характеризующих один и тот же набор покупателей.
#
# Перед этапом обучения модели необходимо агрегировать все признаки из датасетов `market_file`, `market_money` и `market_time`в одном датафрейме. Информация из датасета `money` не понадобится при обучении модели.
#
# Для начала я создам новый датафрейм `data` со значениями из `market_file`. В качестве индексов задам значения столбца `id` - это возможно, потому что мы убедились, что они уникальны в [пункте 2.4.2](#Обработка-неявных-дубликатов).

# %%
# формирование нового датафрейма:
data = market_file.set_index('id').copy()

# вывод двух случайных строк data:
data.sample(2)
# Out:
#        Покупательская_активность Тип_сервиса Разрешить_сообщать  \
# id
# 215469                 Снизилась     премиум                 да
# 215747                 Снизилась    стандарт                 да
#
#         Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# id
# 215469                4.10                     3           813
# 215747                3.50                     5           452
#
#         Акционные_покупки Популярная_категория  \
# id
# 215469               0.22    Домашний текстиль
# 215747               0.93     Товары для детей
#
#         Средний_просмотр_категорий_за_визит  \
# id
# 215469                                    3
# 215747                                    1
#
#         Неоплаченные_продукты_штук_квартал  Ошибка_сервиса  Страниц_за_визит
# id
# 215469                                   3               4                 5
# 215747                                   5               5                 4

# %% [markdown]
# Теперь рассмотрим датасет `market_money`:

# %%
display(market_money.head(3))
print(f"Уникальные значения признака 'Период': {market_money['Период'].unique()}")
# Out:
#        id               Период  Выручка
# 0  215348  препредыдущий_месяц     0.00
# 1  215348        текущий_месяц  3293.10
# 2  215348     предыдущий_месяц     0.00
# Уникальные значения признака 'Период': ['препредыдущий_месяц' 'текущий_месяц' 'предыдущий_месяц']

# %% [markdown]
# Датасет содержит информацию о выручке за 3 периода:
# * препредыдущий_месяц
# * предыдущий_месяц
# * текущий_месяц
#
# Необходимо преобразовать датасет, чтобы для каждого `id` отображалась выручка за 3 соответствующих периода.

# %%
market_money_new = market_money.pivot_table(index='id', columns='Период', values='Выручка')
market_money_new.head(2)
# Out:
# Период  предыдущий_месяц  препредыдущий_месяц  текущий_месяц
# id
# 215348              0.00                 0.00        3293.10
# 215349           5216.00              4472.00        4971.60

# %% [markdown]
# Переименую заголовки с целью повысить информативность:
#
# Текущее значение|Новое значение
# -|-
# препредыдущий_месяц|Выручка_пре_пре_мес
# предыдущий_месяц|Выручка_пред_мес
# текущий_месяц|Выручка_тек_мес

# %%
# переименование заголовков:
market_money_new.rename(columns={
    'препредыдущий_месяц':'Выручка_пре_пре_мес',
    'предыдущий_месяц':'Выручка_пред_мес',
    'текущий_месяц':'Выручка_тек_мес'
}, inplace=True)

# упорядочивание признаков:
market_money_new = market_money_new[['Выручка_пре_пре_мес', 'Выручка_пред_мес', 'Выручка_тек_мес']]

# вывод значений:
market_money_new.head(2)
# Out:
# Период  Выручка_пре_пре_мес  Выручка_пред_мес  Выручка_тек_мес
# id
# 215348                 0.00              0.00          3293.10
# 215349              4472.00           5216.00          4971.60

# %% [markdown]
# Отобразим строку с `id`=215348 для датасетов `data` и `market_money_new`:

# %%
display(data[data.index==215348])
display(market_money_new[market_money_new.index==215348])
# Out:
#        Покупательская_активность Тип_сервиса Разрешить_сообщать  \
# id
# 215348                 Снизилась     премиум                 да
#
#         Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# id
# 215348                3.40                     5           121
#
#         Акционные_покупки Популярная_категория  \
# id
# 215348               0.00     Товары для детей
#
#         Средний_просмотр_категорий_за_визит  \
# id
# 215348                                    6
#
#         Неоплаченные_продукты_штук_квартал  Ошибка_сервиса  Страниц_за_визит
# id
# 215348                                   2               1                 5
# Период  Выручка_пре_пре_мес  Выручка_пред_мес  Выручка_тек_мес
# id
# 215348                 0.00              0.00          3293.10

# %% [markdown]
# Объединим данные датасеты:

# %%
# объединение:
data = data.join(market_money_new)

# вывод строки c id=215348:
data[data.index==215348]
# Out:
#        Покупательская_активность Тип_сервиса Разрешить_сообщать  \
# id
# 215348                 Снизилась     премиум                 да
#
#         Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# id
# 215348                3.40                     5           121
#
#         Акционные_покупки Популярная_категория  \
# id
# 215348               0.00     Товары для детей
#
#         Средний_просмотр_категорий_за_визит  \
# id
# 215348                                    6
#
#         Неоплаченные_продукты_штук_квартал  Ошибка_сервиса  Страниц_за_визит  \
# id
# 215348                                   2               1                 5
#
#         Выручка_пре_пре_мес  Выручка_пред_мес  Выручка_тек_мес
# id
# 215348                 0.00              0.00          3293.10

# %% [markdown]
# Отлично! Стыковка прошла успешно! Работаем дальше!
#
# Рассмотрим датасет `market_time`:

# %%
display(market_time.head(2))
print(f"Уникальные значения признака 'Период': {market_time['Период'].unique()}")
# Out:
#        id            Период  Минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдущий_месяц     13
# Уникальные значения признака 'Период': ['текущий_месяц' 'предыдущий_месяц']

# %% [markdown]
# Датасет содержит информацию о времени пребывания покупателя на сайте за 2 периода:
# * предыдущий_месяц
# * текущий_месяц
#
# Необходимо преобразовать датасет, чтобы для каждого `id` отображалось время за 2 соответствующих периода.

# %%
market_time_new = market_time.pivot_table(index='id', columns='Период', values='Минут')
market_time_new.head(2)
# Out:
# Период  предыдущий_месяц  текущий_месяц
# id
# 215348                13             14
# 215349                12             10

# %% [markdown]
# Переименую заголовки с целью повысить информативность:
#
# Текущее значение|Новое значение
# -|-
# предыдущий_месяц|Время_пред_мес
# текущий_месяц|Время_тек_мес

# %%
# переименование заголовков:
market_time_new.rename(columns={
    'предыдущий_месяц':'Время_пред_мес',
    'текущий_месяц':'Время_тек_мес'
}, inplace=True)

# вывод значений:
market_time_new.sample(2)
# Out:
# Период  Время_пред_мес  Время_тек_мес
# id
# 216389              17             13
# 216009              13             17

# %% [markdown]
# Присоединим `market_time_new` к датасету `data`:

# %%
data = data.join(market_time_new)
data.sample(2)
# Out:
#        Покупательская_активность Тип_сервиса Разрешить_сообщать  \
# id
# 216381           Прежний уровень    стандарт                 да
# 216588           Прежний уровень    стандарт                нет
#
#         Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# id
# 216381                4.20                     4           201
# 216588                4.30                     4           166
#
#         Акционные_покупки                  Популярная_категория  \
# id
# 216381               0.23  Мелкая бытовая техника и электроника
# 216588               0.13        Техника для красоты и здоровья
#
#         Средний_просмотр_категорий_за_визит  \
# id
# 216381                                    5
# 216588                                    4
#
#         Неоплаченные_продукты_штук_квартал  Ошибка_сервиса  Страниц_за_визит  \
# id
# 216381                                   3               5                18
# ...

# %% [markdown]
# Структура итогового набора данных:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1299 entries, 215348 to 216647
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Покупательская_активность            1299 non-null   object
#  1   Тип_сервиса                          1299 non-null   object
#  2   Разрешить_сообщать                   1299 non-null   object
#  3   Маркет_актив_6_мес                   1299 non-null   float64
#  4   Маркет_актив_тек_мес                 1299 non-null   int64
#  5   Длительность                         1299 non-null   int64
#  6   Акционные_покупки                    1299 non-null   float64
#  7   Популярная_категория                 1299 non-null   object
#  8   Средний_просмотр_категорий_за_визит  1299 non-null   int64
#  9   Неоплаченные_продукты_штук_квартал   1299 non-null   int64
#  10  Ошибка_сервиса                       1299 non-null   int64
# ...

# %% [markdown]
# **Выводы:**
# * На основе данных из датасетов `market_file`, `market_money` и `market_time` сформирован новый датасет `data`.
# * Данные о выручке из датасета `market_money` включены в итоговый датасет раздельно для каждого периода - 'препредыдущий_месяц', 'текущий_месяц', 'предыдущий_месяц'.
# * Данные о времени пребывания покупателя из датасета `market_time` включены в итоговый датасет раздельно для каждого периода - 'текущий_месяц' 'предыдущий_месяц'
# * Итоговый датасет содержит 16 обучающих признаков и 1 целевой признак

# %% [markdown]
# <div style="border:solid orange 2px; padding: 20px">
# <font color='red'>*</font> <i>Примечание</i>: по условию проекта необходимо отобрать "клиентов с покупательской активностью не менее трёх месяцев". В процессе выполнения проекта возник вопрос как правильно трактовать это условие.
#
# Проверку покупательской активности я осуществил в пункте <a href="#Отбор-клиентов-с-покупательской-активностью-не-менее-трёх-месяцев">3.3 Отбор клиентов с покупательской активностью не менее трёх месяцев</a>, трактовав условие следующим образом:<br>
# ⠀⠀• "хотя бы одно значение выручки за период последних трех месяцев ненулевое" | "что-либо покупали в период трех месяцев"<br>
# ⠀⠀либо<br>
# ⠀⠀• "суммарная выручка клиента за последние три месяца не равна нулю".
#
# Альтернативная трактовка условия: хотя бы одно значение выручки за период нулевое.
#
# Отфильтровать неактивных клиентов можно используя код:

# %%
# фильтрация клиентов по суммарной выручке:

# формирование списка столбцов с выручкой -
# можно задать автоматически на случай если появятся 
# столбцы с выручкой за новые периоды:
profit_rows = [i for i in data.columns if 'Выручка' in i]

# фильтрация датасета по суммарной выручке > 0
data = data[data[profit_rows].sum(axis=1) > 0]

# %%
# отфильтровать клиентов, у которых хотя бы одно значение выручки = 0:
data[data[profit_rows].eq(0).any(axis=1)].index.to_list()
# Out:
# [215348, 215357, 215359]

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ## Корреляционный анализ
#
# Отобразим матрицу диаграмм рассеяния для количественных признаков.
#
# Кодировка цветов на диаграммах:
#
# Цвет|Покупательская активность
# -|:-
# <font color='#1f77b4' size='6'>●</font>|Прежний уровень
# <font color='red' size='6'>●</font>|Снизилась

# %%
# задание цветовой карты:
colormap = np.where(data['Покупательская_активность'] == 'Прежний уровень', '#1f77b4', 'red')

# отрисовка матрицы диаграмм рассеяния, 
# для удобства видоизменяю отображение заголовков, разделив на строки
pd.plotting.scatter_matrix(data.rename(columns=lambda x: x.replace('_','\n')), c=colormap, s=10, alpha=0.7, 
                           figsize=(15, 15), diagonal='kde', range_padding=0.3)
plt.suptitle("Матрица диаграмм рассеяния", y=0.9)
plt.show()

# %% [markdown]
# Поскольку в таблице наших данных содержатся как количественные, так и категориальные признаки - стандартный расчет коэффициентов корреляции Пирсона не подойдет, поскольку он производит расчет зависимости только среди количественных признаков.
#
# Для расчета взаимозависимости признаков будем использовать коэффициент корреляции Фи, $\phi_{k}$.
#
# Сформируем матрицу корреляции со значениями $\phi_{k}$ для наших данных. Расчет производится для всех признаков кроме `id`.

# %%
# создаём список с наименованиями непрерывных признаков:
interval_cols = ['Маркет_актив_6_мес', 'Длительность', 'Акционные_покупки', 'Выручка', 
                 'Выручка_пре_пре_мес', 'Выручка_пред_мес', 'Выручка_тек_мес', ]

# формируем матрицу корреляции:
phik_overview = data.phik_matrix(interval_cols=interval_cols)
phik_overview
# Out:
#                                      Покупательская_активность  Тип_сервиса  \
# Покупательская_активность                                 1.00         0.13
# Тип_сервиса                                               0.13         1.00
# Разрешить_сообщать                                        0.00         0.29
# Маркет_актив_6_мес                                        0.54         0.09
# Маркет_актив_тек_мес                                      0.00         0.05
# Длительность                                              0.09         0.41
# Акционные_покупки                                         0.50         0.04
# Популярная_категория                                      0.30         0.07
# Средний_просмотр_категорий_за_визит                       0.54         0.18
# Неоплаченные_продукты_штук_квартал                        0.40         0.11
# Ошибка_сервиса                                            0.22         0.08
# ...

# %% [markdown]
# Отобразим матрицу корреляции в виде тепловой карты:

# %%
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Oranges',
    title=r'Матрица корреляции $\phi_K$',
    fontsize_factor=1.5,
    figsize=(20, 15)
)
plt.grid(visible=False)
plt.show()

# %% [markdown]
# Необходимо проверить данные на наличие мультиколлинеарности признаков.
#
# Согласно информации из <abbr title="Спринт 9/25 → Тема 8/11: Метрики в задаче классификации → Урок 2/7: Логистическая регрессия: ограничения модели">теоретического курса</abbr> о мультиколлинеарности говорят при значении коэффициента корреляции от 0.9 до 0.95 по модулю</font>.
#
# Проверим, есть ли такие значения:

# %%
# список для фиксации количества превышений phi >= 0.9:
phi_list = []

# перебор признаков phik_overview:
for c in phik_overview.columns:
    high_phi_values = len(phik_overview[phik_overview[c] >= 0.9].drop(c))
    
    # добавляем значения: [признак, количество превышений]
    phi_list.append([c, high_phi_values])

# отображаем данные в виде датафрейма:
df_phi = pd.DataFrame(data=phi_list, columns=['Признак', 'Количество превышений'])
display(df_phi)

# выводим итог:
print(f"Всего признаков с мультиколлинеарностью: {df_phi[df_phi['Количество превышений'] > 0].shape[0]}")
# Out:
#                                 Признак  Количество превышений
# 0             Покупательская_активность                      0
# 1                           Тип_сервиса                      0
# 2                    Разрешить_сообщать                      0
# 3                    Маркет_актив_6_мес                      0
# 4                  Маркет_актив_тек_мес                      0
# 5                          Длительность                      0
# 6                     Акционные_покупки                      0
# 7                  Популярная_категория                      0
# 8   Средний_просмотр_категорий_за_визит                      0
# 9    Неоплаченные_продукты_штук_квартал                      0
# 10                       Ошибка_сервиса                      0
# 11                     Страниц_за_визит                      0
# 12                  Выручка_пре_пре_мес                      0
# 13                     Выручка_пред_мес                      0
# ...

# %% [markdown]
# А также проверим какие признаки показывают очень слабую корреляцию с целевым признаком ($\phi_K < 0.1$):

# %%
low_phi = phik_overview[phik_overview['Покупательская_активность'] < 0.1]
print(f'Всего признаков с низкой корреляцией с целевым признаком: {low_phi.shape[0]}')
print(low_phi.index.to_list())
# Out:
# Всего признаков с низкой корреляцией с целевым признаком: 3
# ['Разрешить_сообщать', 'Маркет_актив_тек_мес', 'Длительность']

# %% [markdown]
# **Вывод**:
# * В имеющемся наборе данных отсутствуют признаки с мультиколлинеарностью ($\phi_k \geq 0.9$)
# * В имеющемся наборе данных явно не наблюдается утечка данных, хотя необходимо зафиксировать высокую корреляцию между целевым признаком `Покупательская_активность` и обучающим признаком `Страниц_за_визит` — $\phi_k = 0.75$
# * Признаки `Разрешить_сообщать`, `Маркет_актив_тек_мес`, `Длительность` показывают низкую степень корреляции с целевым признаком.

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ## Использование пайплайнов
# Согласно задаче исследования, необходимо построить модель, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца.
#
# Целевой признак `Покупательская_активность` представлен значениями:
# * `Снизилась`
# * `Прежний уровень`
#
# При обучении модели необходимо решить задачу бинарной классификации.
#
# Сформируем переменные содержащие значения обучающих и целевого признаков.
#
# Формирование обучающих признаков:

# %%
X = data.drop(['Покупательская_активность'], axis=1)

# %% [markdown]
# Формирование целевого признака:

# %%
y = data['Покупательская_активность']

# %% [markdown]
# Далее разобьем имеющиеся у нас данные на обучающую и тестовую выборку:
# * Имеющийся объем данных делится на выборки в пропорции:
# <span style="border-width:2px; border-style:solid; border-color:#4d74f9; padding: 3px;">75% {обучающая}</span> + <span style="border-width:2px; border-style:solid; border-color:#4d74f9; padding: 3px;">25% {тестовая}</span>
# * Поскольку в [целевом признаке присутствует дисбаланс данных](#Признак-"Покупательская_активность"-(целевой-признак)), чтобы не допустить получение выборок с разной структурой - при раздении данных нужно применить стратификацию: `stratify = y`

# %%
# переменная задающая размер тестовой выборки:
TEST_SIZE = 0.25

# разбиение обучающих и целевого признака на выборки:
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size = TEST_SIZE,
    random_state = RANDOM_STATE,
    stratify = y)

# %% [markdown]
# Проверим размерность получившихся выборок:

# %%
{X_train.shape, y_train.shape}, {X_test.shape, y_test.shape}
# Out:
# ({(974,), (974, 16)}, {(325,), (325, 16)})

# %% [markdown]
# Перед тем как искать лучшую модель, закодируем строковые классы целевого признака числами — так вычисления выполнятся быстрее. Сделать это можно с помощью кодировщика **LabelEncoder**. Он переведёт строковые значения целевого признака в порядковые числа.
#
# Создаем экземпляр класса **LabelEncoder** для кодирования целевого признака:

# %%
label_encoder = LabelEncoder()

# %% [markdown]
# Обучаем модель и трансформируем выборки:

# %%
y_train = label_encoder.fit_transform(y_train)
y_test  = label_encoder.fit_transform(y_test)

# %% [markdown]
# Проверим как закодировались значения:

# %%
print("y_train:")
for i in np.unique(y_train):
    print(i, label_encoder.inverse_transform([i]))
print()
print("y_test:")
for i in np.unique(y_test):
    print(i, label_encoder.inverse_transform([i]))
# Out:
# y_train:
# 0 ['Прежний уровень']
# 1 ['Снизилась']
#
# y_test:
# 0 ['Прежний уровень']
# 1 ['Снизилась']

# %% [markdown]
# Кодирование целевого признака прошло согласно схеме:
#
# Значение|Код
# -|-
# Прежний уровень|0
# Снизилась|1

# %% [markdown]
# Далее необходимо сформировать списки, где будут обозначены типы кодирования и масштабирования признаков.
#
# * Категориальные признаки, которые кодируются **OneHotEncoder**:
#   * 'Популярная_категория'
# * Категориальные признаки, которые кодируются **OrdinalEncoder**:
#   * 'Тип_сервиса'
#   * 'Разрешить_сообщать'
# * Числовые признаки, которые будут **масштабированы**:
#   * 'Маркет_актив_6_мес',
#   * 'Маркет_актив_тек_мес',
#   * 'Длительность',
#   * 'Акционные_покупки',
#   * 'Средний_просмотр_категорий_за_визит',
#   * 'Неоплаченные_продукты_штук_квартал',
#   * 'Ошибка_сервиса',
#   * 'Страниц_за_визит',
#   * 'Выручка_пре_пре_мес',
#   * 'Выручка_пред_мес',
#   * 'Выручка_тек_мес',
#   * 'Время_пред_мес',
#   * 'Время_тек_мес'

# %%
# создаём списки с названиями признаков:
ohe_columns = ['Популярная_категория'] # признаки OneHotEncoder-кодирования 
ord_columns = ['Тип_сервиса', 'Разрешить_сообщать'] # признаки OrdinalEncoder-кодирования

# %%
num_columns = X_train.select_dtypes(exclude='object').columns.tolist() # числовые признаки для масштбирования

# %% [markdown]
# Обозначим пайплайн **OneHotEncoder**-кодирования:
# * При кодировании неизвестных категорий могут возникнуть пропуски `missing_values=np.nan`. Обработать их поможет инструмент **SimpleImputer**, который заменит недостающие значения на моду: `strategy='most_frequent'`
# * Кодирование методом OHE
#   * `drop='first'` - обработка дамми-ловушек - каждый первый столбец при кодировании качественного признака будет удалён
#   * `handle_unknown='ignore'` - игнорируем неизвестные категории
#   * `sparse_output=False` - устанавливает формат данных, в котором кодировщик вернёт результаты. Значение `False` позволит изучать результаты кодирования визуально в ходе исследования

# %%
# создаём пайплайн для подготовки признаков из списка ohe_columns: заполнение пропусков и OHE-кодирование
# SimpleImputer + OHE
ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False)) 
    ]
    )

# %% [markdown]
# Обозначим пайплайн **OrdinalEncoder**-кодирования:
# * `simpleImputer_before_ord` - заполнение пропусков самым часто встречающимся значением с помощью **SimpleImputer**.
# * `ord` - проведение Ordinal-кодирование с помощью OrdinalEncoder.
#   * `handle_unknown='use_encoded_value'`, `unknown_value=np.nan` - неизвестным категория присвоится значение `NaN`
# * `simpleImputer_after_ord` - заполнение пропусков, которые появляются после Ordinal-кодирования.

# %%
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=np.nan)),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# %% [markdown]
# Создаём общий пайплайн для подготовки данных:

# %%
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', MinMaxScaler(), num_columns)
    ],
    remainder='passthrough'
)

# %% [markdown]
# Создаём итоговый пайплайн: подготовка данных и модель:

# %%
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

# %% [markdown]
# Создаем сетку, содержающую набор моделей и их гиперпараметров. Исследуются модели:
#
# Название модели|Гиперпараметры
# -|:-
# KNeighborsClassifier|n_neighbors: [2,8,18,45]
# DecisionTreeClassifier|max_depth: [2,4,5,7],<br>max_features: [2,5,7,10]
# LogisticRegression|C: [1,3,5,7,9]
# SVC|C: [0.1, 1, 10],<br>gamma: ['scale', 'auto']
#
# Ко всем моделям применяются методы масштабирования числовых признаков **StandardScaler** и **MinMaxScaler**.

# %% [markdown]
# <div style="border:solid orange 2px; padding: 20px">
# <font color='red'>*</font> <i>Примечание</i>: значения гиперпаметров получены путем перебора значений для каждой модели и выбора из всех значений некой комбинации обеспечивающей высокое значение метрики. Для финальной сетки оставил небольшое число вариаций с целью сократить время на обучения модели.

# %%
param_grid = [
    # словарь для модели KNeighborsClassifier()
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': [2,8,18,45],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': [2,4,5,7],
        'models__max_features': [2,5,7,10],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE,
            solver='liblinear',
            penalty='l1'
        )],
        'models__C': [1,3,5,7,9],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели SVC()
    {
        'models': [SVC(random_state=RANDOM_STATE, kernel='rbf', probability=True)], 
        'models__C': [0.1, 1, 10],
        'models__gamma': ['scale', 'auto'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
}
]

# %% [markdown]
# Создаем пайплайн с приминением автоматизированного поиска гиперпараметров **GridSearchCV**:
# * `cv=5` - применяется кросс-валидация из 5 блоков
# * `scoring='roc_auc'` - в качестве метрики качества моделей используется ROC-AUC. Выбор в пользу данной метрики обуславливается поставленной задачей, структурой и качеством данных:
#   * Для задачи классификации покупательской активности метрика ROC-AUC отлично подходит, поскольку она оценивает качество решений модели в наиболее общем виде, учитывая все возможные пороговые значения.
#   * ROC-AUC показывает, насколько хорошо модель различает между положительными и отрицательными классами, учитывая баланс между ложными срабатываниями и пропусками.
#   * ROC-AUC позволяет сравнивать различные модели на одном и том же наборе данных, помогая выбрать лучшую модель для конкретной задачи.
#   * Метрика ROC-AUC подходит для бинарной классификации с дисбалансом по классам
# * `n_jobs=-1` - количество вычислительных мощностей (чтобы считалось быстрее, указывают `-1`)

# %%
grid_search = GridSearchCV(
    pipe_final,
    param_grid,
    cv=5,
    scoring='roc_auc',
    n_jobs=-1
)

# %% [markdown]
# Запуск пайплайна:

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ohe',
#                                                                          Pipeline(steps=[('simpleImputer_ohe',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('ohe',
#                                                                                           OneHotEncoder(drop='first',
#                                                                                                         handle_unknown='ignore',
#                                                                                                         sparse_output=False))]),
# ...

# %% [markdown]
# Отобразим параметры лучшей модели и полученную метрику на кросс-валидации:

# %%
print('Лучшая модель и её параметры:\n\n', grid_search.best_estimator_)
print('Метрика лучшей модели на кросс-валидации:', grid_search.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['Популярная_категория']),
#                                                  ('ord',
# ...

# %% [markdown]
# Рассчитаем метрику модели на тренировочных данных:

# %%
y_train_pred = grid_search.predict_proba(X_train)[:,1]
print(f'Метрика ROC-AUC на train-выборке: {roc_auc_score(y_train, y_train_pred)}')
# Out:
# Метрика ROC-AUC на train-выборке: 0.9581550855812252

# %% [markdown]
# Для сравнения отобразим топ-10 моделей с лучшими результатами:

# %%
result = pd.DataFrame(grid_search.cv_results_)

result[['rank_test_score', 'param_models', 'mean_test_score','params']
].sort_values('rank_test_score').head(10).style.format({'mean_test_score': '{:.4f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_cf4bf_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rank_test_score</th>        <th class="col_heading level0 col1" >param_models</th>        <th class="col_heading level0 col2" >mean_test_score</th>        <th class="col_heading level0 col3" >params</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cf4bf_level0_row0" class="row_heading level0 row0" >84</th>
#                         <td id="T_cf4bf_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_cf4bf_row0_col1" class="data row0 col1" >SVC(probability=True, random_state=42)</td>
#                         <td id="T_cf4bf_row0_col2" class="data row0 col2" >0.9176</td>
# ...

# %% [markdown]
# Сделаем прогноз для тестовых данных и рассчитаем метрику:

# %%
y_test_pred = grid_search.predict_proba(X_test)[:,1]
roc_auc_best = roc_auc_score(y_test, y_test_pred)
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_best}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.9202776440378752

# %% [markdown]
# Чтобы оценить адекватность модели в задачах классификации, нужно сравнить её со случайной. Например рассчитать метрику качества для случая, когда целевой признак заполнен популярным значением. Если метрика качества лучшей модели больше, чем у "случайной", значит модель прошла проверку на адекватность.
#
# Для данной цели я использую модель **DummyClassifier** из библиотеки `sklearn`. Данная модель формирует предсказания на простом принципе - заполняя значения какой-либо постоянной величиной - в нашем случае самым популярным значением `strategy="most_frequent"`.

# %%
# инициализация модели:
dummy_clf = DummyClassifier(strategy="most_frequent")

# обучение модели на train-выборке:
dummy_clf.fit(X_train, y_train)

# формирование предсказаний на основе признаков test-выборки:
dummy_predictions_test = dummy_clf.predict(X_test)

# расчет метрики:
roc_auc_dummy = roc_auc_score(y_test, dummy_predictions_test)

# оценка результата:
if roc_auc_best > roc_auc_dummy:
    print("✅ Модель прошла проверку на адекватность:",
          f"метрика модели '{grid_search.best_estimator_.steps[-1][1].__class__.__name__}' ({roc_auc_best:.2f})",
          f"выше, чем у случайной ({roc_auc_dummy})")
else:
    print("Модель нуждается в доработке: метрика качества низкая 👎")
# Out:
# ✅ Модель прошла проверку на адекватность: метрика модели 'SVC' (0.92) выше, чем у случайной (0.5)

# %% [markdown]
# **Выводы:**
# * Для решения задачи бинарной классификации предсказания целевого признака "покупательская активность" произведен поиск лучшей модели МО.
# * Поиск модели осуществлялся с помощью пайплайна - инструмента, который позволяет автоматизировать действия по подготовке данных, обучению моделей и оценке их качества.
# * Перебор значений осуществлялся с помощью **GridSearchCV** - автоматизированного инструмента поиска гиперпараметров.
# * Для решения задачи обучались следующие модели классификации:
#   * **KNeighborsClassifier**
#   * **DecisionTreeClassifier**
#   * **LogisticRegression**
#   * **SVC**
# * В процессе обучения моделей применялась кросс-валидация из 5 блоков
# * Метрика оценки качества моделей - ROC-AUC
# * Лучший результат на обучающих данных показала модель **SVC**(`kernel='rbf'`, `C=1`, `gamma='auto`).
# * Метрика ROC-AUC лучшей модели на тренировочной выборке: 0.92.
# * Модель прошла проверку на адекватность.
# * В десятку моделей с лучшим результатом попали KNeighborsClassifier, SVC, LogisticRegression, показав хорошие значения метрики, которые близки друг к другу. Модели DecisionTreeClassifier не удалось достичь аналогичных результатов.

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ## Анализ важности признаков
#
# Оценим важность признаков для лучшей модели с помощью метода SHAP.
#
# Для начала, зададим переменную содержащую инфомарцию о лучшей модели:

# %%
best_model = grid_search.best_estimator_

# %% [markdown]
# Предобработаем данные методами используемыми моделью:

# %%
X_test_preprocessed = best_model.named_steps['preprocessor'].transform(X_test)

# %% [markdown]
# Создадим список с заголовками предобработанных признаков. Для удобочитаемости ограничим длину заголовка 20-символами:

# %% [raw]
# feature_names = [i[5:25] for i in grid_search.best_estimator_.named_steps['preprocessor'].get_feature_names_out()]
# feature_names

# %%
# еще немного изменил формат вывода заголовков
feature_names = [i[5:].replace('Популярная_категория','кат')[:25] for 
 i in grid_search.best_estimator_.named_steps['preprocessor'].get_feature_names_out()]
feature_names
# Out:
# ['кат_Косметика и аксесуары',
#  'кат_Кухонная посуда',
#  'кат_Мелкая бытовая техник',
#  'кат_Техника для красоты и',
#  'кат_Товары для детей',
#  'Тип_сервиса',
#  'Разрешить_сообщать',
#  'Маркет_актив_6_мес',
#  'Маркет_актив_тек_мес',
#  'Длительность',
#  'Акционные_покупки',
#  'Средний_просмотр_категори',
#  'Неоплаченные_продукты_шту',
#  'Ошибка_сервиса',
#  'Страниц_за_визит',
#  'Выручка_пре_пре_мес',
#  'Выручка_пред_мес',
#  'Выручка_тек_мес',
#  'Время_пред_мес',
#  'Время_тек_мес']

# %% [markdown]
# Зададим explainer для SHAP-значений:

# %%
explainer = shap.Explainer(best_model['models'].predict, X_test_preprocessed)

# %% [markdown]
# Рассчитаем SHAP-значения признаков:

# %%
shap_values = explainer(pd.DataFrame(data=X_test_preprocessed, columns=feature_names))
# Out:
# PermutationExplainer explainer: 326it [04:01,  1.31it/s]

# %% [markdown]
# Отобразим SHAP-значения на диаграмме beeswarm:

# %% [raw]
# shap.plots.beeswarm(shap_values, order=shap_values.abs.mean(0), max_display=None, plot_size=(13,7));

# %%
shap.plots.beeswarm(shap_values, order=shap_values.abs.mean(0), max_display=None, plot_size=(13,7), show=False)
plt.ylabel('Наименование признаков')
plt.xlabel('SHAP-значения (влияние на целевой признак)')
plt.title('Диаграмма beeswarm SHAP-значений признаков')
plt.show()

# %% [markdown]
# Отобразим одно наблюдение в виде waterfall-диаграммы:

# %%
shap.plots.waterfall(shap_values[274], max_display=10, show=False)
plt.title('Диаграмма waterfall SHAP-значений признаков')
fig = plt.gcf()
ax = fig.axes[0] 
ax.set_ylabel('Наименование признаков')
ax.set_xlabel('SHAP-значения (влияние на целевой признак)')
plt.show()

# %% [markdown]
# Отобразим общий вклад признаков в прогнозы модели в виде столбчатой диаграммы:

# %%
shap.summary_plot(shap_values, plot_type='bar', show=False)
plt.ylabel('Наименование признаков')
plt.xlabel('SHAP-значения (влияние на целевой признак)')
plt.title('Столбчатая диаграмма SHAP-значений признаков')
plt.show()

# %% [markdown]
# **Выводы**:
# * Признаки, которые сильнее всего влияют на целевой признак:
#
# Признак|Описание
# -|:-
# Страниц_за_визит|Среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца
# Время_пред_мес|Время (в минутах), которое покупатель провёл на сайте в течение предыдущего месяца
# Время_тек_мес|Время (в минутах), которое покупатель провёл на сайте в течение текущего месяца
# Неоплаченные_продукты_штук_квартал|Общее число неоплаченных товаров в корзине за последние 3 месяца
# Акционные_покупки|Среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев
# Средний_просмотр_категорий_за_визит|Сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца
# Выручка_пре_пре_мес|Выручка, которую получает магазин с покупателя, то есть сколько покупатель всего потратил два месяца назад
# Маркет_актив_6_мес|Cреднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6
#
#
# * Признаки, которые мало значимы для модели:
#
# Признак|Описание
# -|:-
# кат_Кухонная посуда|Самая популярная категория товаров у покупателя за последние 6 месяцев ('Кухонная посуда')
# Разрешить_сообщать_нет|Информация о том, можно ли присылать покупателю дополнительные предложения о товаре
# Тип_сервиса_стандарт|Уровень сервиса покупателя
# кат_Косметика и аксесуары|Самая популярная категория товаров у покупателя за последние 6 месяцев ('Косметика и аксесуары')
# Маркет_актив_тек_мес|Cреднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя в текущем месяце
#
# * Признаки оказывающее большое внимание должны быть основополагающими при моделировании. Им стоит уделять основное внимание на процессе предобработки. На основе этих признаков можно создать производные признаки, например, можно использовать соотношение времени, проведенного на сайте, к числу просмотренных страниц, чтобы оценить вовлеченность клиента.
# * Некоторые идеи, которые могут быть использованы интернет-магазином «В один клик» для общего повышения покупательской активности.
#   * *Увеличение времени на сайте*. Можно разработать контент, который будет удерживать пользователей дольше, например, подробные описания товаров, отзывы, рекомендации и т.д.
#   * *Повышение вовлеченности*. Можно поощрять клиентов просматривать больше страниц и категорий через персонализированные предложения или интерактивные элементы на сайте.
#   * *Контроль маркетинговых коммуникаций*. Анализ признака отображающего среднемесячное значение маркетинговых коммуникаций компании показывает, что больше коммуникаций может привести к лучшим результатам. Но важно не переусердствовать, чтобы не вызвать раздражение у клиентов. Можно оптимизировать частоту и качество коммуникаций.
#   * *Управление покупками по акции*. Слишком частые акции могут привести к привыканию клиентов к скидкам, что снижает доход с каждого клиента. Можно рассмотреть стратегию акций так, чтобы они стимулировали покупки, но не деградировали ценность предложения.
#   * *Обработка неоплаченных товаров*. Высокие значения этого признака снижают покупательскую активность. Это может указывать на проблемы с корзиной покупателя, процессом оформления заказа или на недостаток доверия. Улучшение пользовательского опыта на этих этапах, возможно, через напоминания или упрощение процесса покупки, поможет снизить это значение.

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ## Сегментация покупателей
#
# Потеря ключевых клиентов для любой компании является негативным фактором. Поэтому в качестве первого сегмента я бы хотел рассмотреть группу клиентов с наиболее высокой прибыльностью и высокой вероятностью снижения покупательской активности.

# %% [markdown]
# ### Первый сегмент

# %% [markdown]
# Данные о прибыльности клиента можно взять из датасета `money`.
#
# Условно разделю покупателей на 3 категории по уровню прибыльности - "средняя", "ниже среднего" и "выше среднего":

# %%
plt.figure(figsize=(8, 5))
bins = plt.hist(money['Прибыль'], bins=3, edgecolor='w')
profit_threshold = bins[1][2]
plt.text(1.3,bins[0][0]+25, 'Ниже среднего'), plt.text(3.8,bins[0][1]+13, 'Средняя')
plt.text(5.7,bins[0][2]+25, 'Выше среднего'), plt.ylabel('Частота')
plt.title('Условные категории прибыльности покупателей'), plt.xlabel('Величина среднемесячной прибыли')
plt.legend([f'Порог: {profit_threshold}'])
plt.show()

# %% [markdown]
# Для определения категории клиентов с высокой вероятностью снижения покупательской активности, рассмотрим прогнозные значения присвоения целевого признака.
#
# Для этого предобработаем признаки всего имеющего набора клиентов `X`:

# %%
X_preprocessed = best_model.named_steps['preprocessor'].transform(X)

# %% [markdown]
# Сформируем прогнозные значения для всего набора клиентов, отобразим в виде графика плотности:

# %%
target_proba = best_model['models'].predict_proba(X_preprocessed)[:,1]
pd.Series(target_proba).plot.kde(label="proba")
plt.axvline(0.75, color='r', linestyle='dashed', label="Порог=0.75")
plt.xlabel("Вероятность присвоения признака"), plt.ylabel("Плотность значений")
plt.title('Распределение плотности значений вероятности присвоения признака')
# лейблы целевого признака:
plt.text(0.98, 0.1, "1: Снизилась", size=17, alpha=0.75, rotation=90., ha="center", va="bottom",
         bbox=dict(boxstyle="round", ec=(1., 0.5, 0.5), fc=(1., 0.8, 0.8)))
plt.text(0.02, 0.1, "0: Прежний уровень", size=17, alpha=0.75, rotation=90., ha="center", va="bottom",
         bbox=dict(boxstyle="round", ec='#00a949', fc='#ccefdd'))
plt.xlim(0,1), plt.legend()
plt.show()

# %% [markdown]
# В качестве порога для категории клиентов с высокой вероятностью снижения покупательской активности я взял значение `0.75`: вероятность 75%, что значению будет присвоен класс `1`. Напомню схему кодирования целевого признака:
#
# Значение|Код
# -|-
# Прежний уровень|0
# Снизилась|1
#
# Клиенты имеющие вероятность присвоения признака **выше данного порога** с высокой вероятностью снизят покупательскую активность.

# %% [markdown]
# Сформирую датасет включающий `id` покупатей, вероятность присвоения признака и данные о прибыли:

# %%
df_1 = pd.DataFrame({'id':data.index,
                     'proba':target_proba,
                     'Прибыль':money['Прибыль']
                    })
df_1.head()
# Out:
#        id  proba  Прибыль
# 0  215348   0.70     0.98
# 1  215349   0.98     4.16
# 2  215350   0.22     3.13
# 3  215351   0.94     4.87
# 4  215352   0.99     4.21

# %% [markdown]
# Применю к датасету фильтр:
# * `proba` > 0.75
# * `Прибыль` > `profit_threshold` (5.24)

# %%
df_1 = df_1[(df_1['proba'] > 0.75) & (df_1['Прибыль'] >= profit_threshold)]
df_1.head()
# Out:
#         id  proba  Прибыль
# 20  215368   0.98     6.27
# 43  215391   0.98     5.44
# 52  215400   0.99     6.73
# 53  215401   0.97     7.43
# 65  215413   0.95     5.40

# %% [markdown]
# Графически отображу рассматриваемый сегмент:

# %%
plt.scatter(x=target_proba, y=money['Прибыль'])
y1, y2 =profit_threshold, df_1['Прибыль'].max()
plt.fill_between([0.75, 1], [y1, y1], [y2, y2], color='orange', alpha=0.15, hatch='///')
plt.xlabel("Вероятность присвоения признака"), plt.ylabel("Прибыль")
plt.title('Графическое отображение группы клиентов с высокой вероятностью\nснижения \
покупательской активности и наиболее высокой прибыльностью')
# лейблы целевого признака:
plt.text(1.03, 4, "1: Снизилась", size=17, alpha=0.75, rotation=90., ha="center", va="center",
         bbox=dict(boxstyle="round", ec=(1., 0.5, 0.5), fc=(1., 0.8, 0.8)))
plt.text(-0.016, 4, "0: Прежний уровень", size=17, alpha=0.75, rotation=90., ha="center", va="center",
         bbox=dict(boxstyle="round", ec='#00a949', fc='#ccefdd'))
plt.show()

# %% [markdown]
# На основе датасета `data` сформирую новый датасет для рассматриваемого сегмента. `id` покупателей возьму из датасета `df_1`

# %%
segment_1 = data[data.index.isin(df_1['id'].to_list())]
segment_1.head()
# Out:
#        Покупательская_активность Тип_сервиса Разрешить_сообщать  \
# id
# 215368                 Снизилась     премиум                 да
# 215391                 Снизилась     премиум                 да
# 215400                 Снизилась    стандарт                нет
# 215401                 Снизилась     премиум                 да
# 215413                 Снизилась     премиум                 да
#
#         Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# id
# 215368                3.80                     5           829
# 215391                3.50                     3           754
# 215400                4.40                     5           304
# 215401                3.40                     5           339
# 215413                4.00                     3           759
#
#         Акционные_покупки            Популярная_категория  \
# id
# 215368               0.24  Техника для красоты и здоровья
# 215391               0.30           Косметика и аксесуары
# ...

# %% [markdown]
# Для последующего SHAP-анализа признаков предобработаю данные задам `explainer`

# %%
X_1 = segment_1.drop(['Покупательская_активность'], axis=1)
X_1_preprocessed = best_model.named_steps['preprocessor'].transform(X_1)
explainer = shap.Explainer(best_model['models'].predict, X_1_preprocessed)

# %% [markdown]
# Получу SHAP-значения для рассматриваемого сегмента:

# %%
shap_values = explainer(pd.DataFrame(data=X_1_preprocessed, columns=feature_names))

# %% [markdown]
# Отображу значения в виде графика `beeswarm`:

# %%
shap.plots.beeswarm(shap_values, order=shap_values.abs.mean(0), max_display=None, plot_size=(13,7), show=False)
plt.ylabel('Наименование признаков')
plt.xlabel('SHAP-значения (влияние на целевой признак)')
plt.title('Диаграмма beeswarm SHAP-значений признаков')
plt.show()

# %% [markdown]
# Можно заметить, что для данного сегмента признак `Популярная_категория` более значим, чем для всего набора покупателей. Проверим, какие категории пользуются наибольшим спросом:

# %%
stat_cat(segment_1, 'Популярная_категория',
         labels=['Кухонная\nпосуда', 'Мелкая бытовая\nтехника и\nэлектроника',
                  'Техника\nдля красоты\nи здоровья', 'Косметика\nи аксесуары',
                  'Домашний\nтекстиль', 'Товары\nдля детей'])
# Out:
# Значения признака 'Популярная_категория' распределены следующим образом:
# - Всего значений: 32
# - Уникальных значений: 6 ['Техника для красоты и здоровья' 'Косметика и аксесуары'
#  'Товары для детей' 'Кухонная посуда'
#  'Мелкая бытовая техника и электроника' 'Домашний текстиль']
# В том числе:
# - Техника для красоты и здоровья: 2 (6.25%)
# - Косметика и аксесуары: 11 (34.38%)
# - Товары для детей: 14 (43.75%)
# - Кухонная посуда: 3 (9.38%)
# - Мелкая бытовая техника и электроника: 1 (3.12%)
# - Домашний текстиль: 1 (3.12%)

# %% [markdown]
# **Выводы**:
# * В целом, для данного сегмента влияние признаков такое же как и для всех остальных.
# * Можно зафиксровать более заметное влияние признака с популярной категорией. Наиболее популярные категории:
#   * `Косметика и аксесуары`
#   * `Домашний текстиль`
# * Помимо общих, ранее обозначенных советов для повышения покупательской активности, с учетом специфики категорий покупок, можно добавить:
#   * *Персонализация*. Можно использовать данные о покупательских предпочтениях для создания персонализированных предложений. Например, если клиент часто покупает определенные бренды или типы продуктов, предложить ему новинки или комплементарные товары.
#   * *Программа лояльности*. Можно ввести программу лояльности, где за каждую покупку клиент получает баллы или скидки. Особенно это может быть эффективно для повторных покупок косметики, так как продукты часто требуют регулярного обновления.
#   * *Безопасность и качество*. Донести до покупателей информацию, что все товары соответствуют высоким стандартам безопасности и качества, через сертификаты, отзывы и обзоры.
#   * *Качество обслуживания*. Быстрые ответы на запросы, удобные возвраты и обмены, персонализированные консультации.

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ### Второй сегмент
# В качестве второго сегмента я бы хотел исследовать покупателей премиум-сервиса, у которых возможен прогноз снижения покупательской активности, то есть, `proba` выше 0.5. Условимся, что абсолютно все клиенты данного класса нам дороги, поэтому не будем ограничивать по значению прибыли.
#
# Сформирую датафрейм с данными об `id`, вероятности присвоения признака, прибыли и типе сервиса покупателя:

# %%
df_2 = pd.DataFrame({'id':data.index,
                     'proba':target_proba,
                     'Прибыль':money['Прибыль'],
                     'Тип_сервиса':data['Тип_сервиса'].to_list()
                    })
df_2.head()
# Out:
#        id  proba  Прибыль Тип_сервиса
# 0  215348   0.70     0.98     премиум
# 1  215349   0.98     4.16     премиум
# 2  215350   0.22     3.13    стандарт
# 3  215351   0.94     4.87    стандарт
# 4  215352   0.99     4.21    стандарт

# %% [markdown]
# Отображу на графике рассматриваемый сегмент:

# %%
# Определяем условия для цвета точек
condition = (df_2['Тип_сервиса'] == 'премиум') & (df_2['proba'] > 0.5)

# Разделяем данные на две группы в зависимости от условия
prem_1, prem_0 = df_2[condition], df_2[~condition]

# Точки, удовлетворяющие условию, отображаются красными звездами
plt.scatter(prem_1['proba'], prem_1['Прибыль'], marker=(5,2), s=80, color='red', label='премиум, proba > 0.5')

# Все остальные точки - серым цветом
plt.scatter(prem_0['proba'], prem_0['Прибыль'], marker='.', color='#d3d3d3', alpha=0.55, label='остальные')

# Настройка графика
plt.axvline(0.5, color='orange', linestyle='dashed', label="proba=0.5")
plt.title('Графическое отображение группы покупателей премиум-сервиса, \n\
у которых возможен прогноз снижения покупательской активности')
plt.xlabel('Вероятность присвоения признака')
plt.ylabel('Прибыль')

# лейблы целевого признака:
plt.text(1.03, 4, "1: Снизилась", size=17, alpha=0.75, rotation=90., ha="center", va="center",
         bbox=dict(boxstyle="round", ec=(1., 0.5, 0.5), fc=(1., 0.8, 0.8)))
plt.text(-0.016, 4, "0: Прежний уровень", size=17, alpha=0.75, rotation=90., ha="center", va="center",
         bbox=dict(boxstyle="round", ec='#00a949', fc='#ccefdd'))
plt.legend(bbox_to_anchor=(0.585, 1))
plt.show()

# %% [markdown]
# Применю к данным фильтр:
# * `Тип_сервиса` = `премиум`
# * `proba` > 0.5

# %%
df_2 = df_2[(df_2['proba'] > 0.5) & (df_2['Тип_сервиса'] == 'премиум')]
df_2.head()
# Out:
#         id  proba  Прибыль Тип_сервиса
# 0   215348   0.70     0.98     премиум
# 1   215349   0.98     4.16     премиум
# 14  215362   0.84     3.49     премиум
# 16  215364   0.99     2.67     премиум
# 19  215367   0.99     3.03     премиум

# %% [markdown]
# Сформирую датасет для рассматриваемого сегмента на основе `data`:

# %%
segment_2 = data[data.index.isin(df_2['id'].to_list())]
segment_2.head()
# Out:
#        Покупательская_активность Тип_сервиса Разрешить_сообщать  \
# id
# 215348                 Снизилась     премиум                 да
# 215349                 Снизилась     премиум                 да
# 215362                 Снизилась     премиум                 да
# 215364                 Снизилась     премиум                 да
# 215367                 Снизилась     премиум                 да
#
#         Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# id
# 215348                3.40                     5           121
# 215349                4.40                     4           819
# 215362                4.20                     4           438
# 215364                4.30                     4           708
# 215367                4.20                     4           581
#
#         Акционные_покупки Популярная_категория  \
# id
# 215348               0.00     Товары для детей
# 215349               0.75     Товары для детей
# ...

# %% [markdown]
# Подготовлю данные для SHAP-анализа признаков:

# %%
# выделение обучающих признаков:
X_2 = segment_2.drop(['Покупательская_активность'], axis=1)

# препроцессинг данных:
X_2_preprocessed = best_model.named_steps['preprocessor'].transform(X_2)

# установка explainer:
explainer = shap.Explainer(best_model['models'].predict, X_2_preprocessed)

# получение SHAP-значений:
shap_values = explainer(pd.DataFrame(data=X_2_preprocessed, columns=feature_names))
# Out:
# PermutationExplainer explainer: 147it [01:45,  1.25it/s]

# %% [markdown]
# Отображу SHAP-значения в виде графика `beeswarm`:

# %%
shap.plots.beeswarm(shap_values, order=shap_values.abs.mean(0), max_display=None, plot_size=(13,7), show=False)
plt.ylabel('Наименование признаков')
plt.xlabel('SHAP-значения (влияние на целевой признак)')
plt.title('Диаграмма beeswarm SHAP-значений признаков')
plt.show()

# %% [markdown]
# **Выводы**
# * Набор наиболее влияющих на покупательскую активность признаков, примерно совпадает с теми, что рассмотрены ранее.
# * Обращает внимание большое влияние признаков `Акционные_покупки` и `Неоплаченные_продукты_штук_квартал`.
# * Вдобавок к общим советам, можно добавить следующие идеи для повышения покупательской активности:
#   * *Пересмотр стратегии акционных покупок*. Если высокая доля акционных покупок связана со снижением покупательской активности, возможно, скидки и акции привлекают клиентов, которые в основном покупают только по сниженным ценам. Можно пересмотреть стратегию акций: возможно, стоит сократить частоту или глубину скидок.
#   * *Улучшение процесса оформления заказа*. Высокое количество неоплаченных товаров в корзине может указывать на проблемы с процессом оформления заказа. Можно попытаться упростить и ускорить этот процесс, убедиться, что все шаги интуитивно понятны, и нет технических проблем или слишком больших форм для заполнения.
#   * *Анализ причин отказа*. Можно провести исследование, чтобы понять, почему клиенты оставляют товары в корзине. Это может быть связано с высокими ценами, сомнениями в качестве, отсутствием удобных способов оплаты или доставки.

# %% [markdown]
# [Вернуться к оглавлению](#point0)

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Для данных предоставленных интернет-магазином «В один клик», содержащих информацию о группе признаков отображающих
# * коммуникацию сотрудников компании с клиентом
# * продуктовое поведение покупателя
# * покупательское поведение клиента
# * поведение покупателя на сайте
#
# с поставленными целями
# * построения модели МО, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца
# * выделения сегментов покупателей и разработки для них персонализированных предложений
#
# было проведено исследование, в рамках которого:
# 1. Произведено предварительное изучение и обработка набора данных
# * проверена корректность и соответствие предоставленных данных заявленным заказчиком
# 2. Проведена предварительная обработка данных:
# * типы данных для признаков изменены на подходящие для обработки
# * устранены дубликаты данных
# 3. Проведен исследовательский анализ данных
# * устранены записи содержащие аномальные значения параметров (признак 'Выручка')
# * исследовано распределение значений числовых и категориальных признаков
# * отобраны клиенты с покупательской активностью не менее трёх месяцев
#
# 4. На основе имеющихся датасетов сформирован итоговый набор данных предназначенный для обучения моделей.
# 5. Проведен корреляционный анализ
# * рассчитаны коэффициенты корреляции Фи ($\phi_k$) для признаков датасета
# * данные проверены на наличие мультиколлинеарности
# * определены признаки с низкой степенью корреляции
#
# 6. Для решения задачи бинарной классификации предсказания целевого признака 'покупательская активность' произведен поиск лучшей модели МО.
# * Поиск модели осуществлялся с помощью пайплайна - инструмента, который позволяет автоматизировать действия по подготовке данных, обучению моделей и оценке их качества.
# * Для решения задачи обучались следующие модели классификации:
#   * **KNeighborsClassifier**
#   * **DecisionTreeClassifier**
#   * **LogisticRegression**
#   * **SVC**
# * Метрика оценки качества моделей - ROC-AUC
# * Лучший результат на обучающих данных показала модель **SVC**(`kernel='rbf'`, `C=1`, `gamma='auto`).
# * Метрика ROC-AUC лучшей модели на тренировочной выборке: 0.92.
# * Модель прошла проверку на адекватность.
# 7. Проведен анализ важности признаков
# * Признаки, которые сильнее всего влияют на целевой признак:
#   * Время (в минутах), которое покупатель провёл на сайте в течение предыдущего месяца
#   * Среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца
#   * Время (в минутах), которое покупатель провёл на сайте в течение текущего месяца
# * Признаки, которые мало значимы для модели:
#   * Информация о том, можно ли присылать покупателю дополнительные предложения о товаре
#   * Уровень сервиса покупателя
#   * Выручка, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за предыдущий месяц
# 8. Проведена сегментация покупателей
# * Первый сегмент: группа клиентов с высокой вероятностью снижения покупательской активности и наиболее высокой прибыльностью.
#   * Проведена оценка важности признаков.
#   * На основе проведенного анализа даны рекомендации для повышения покупательской активности сегмента рассматривающие такие факторы как:
#    * Персонализация.
#    * Программа лояльности.
#    * Безопасность и качество.
#    * Качество обслуживания.
# * Второй сегмент: группа клиентов премиум-сервиса, у которых возможен прогноз снижения покупательской активности
#   * Проведена оценка важности признаков.
#   * На основе проведенного анализа даны рекомендации для повышения покупательской активности сегмента рассматривающие такие факторы как:
#    * Пересмотр стратегии акционных покупок
#    * Улучшение процесса оформления заказа
#    * Анализ причин отказа

# %% [markdown]
# [Вернуться к оглавлению](#point0)
